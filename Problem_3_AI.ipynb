# %% [markdown]
# Import Denpendencies, Preprocessing Datas for Model

# %%
import requests
import torch
import torch.nn.functional as F
import torchtext

url = 'https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/'
train_en = [line.split() for line in requests.get(url+"train.en").text.splitlines()]
train_vi = [line.split() for line in requests.get(url+"train.vi").text.splitlines()]
test_en = [line.split() for line in requests.get(url+"tst2013.en").text.splitlines()]
test_vi = [line.split() for line in requests.get(url+"tst2013.vi").text.splitlines()]



MODELNAME= "iwslt15-en-vi-rnn.model"
EPOCH= 10
BATCHSIZE= 32
LR= 0.0001
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

#Make Vocabulary

def make_vocab(train_data, min_freq):
  vocab = {}
  for tokenlist in train_data:
    for token in tokenlist:
      if token not in vocab:
        vocab[token] = 0
      vocab[token]+=1
  vocablist=[('<unk>', 0),('<pad>', 0),('<cls>', 0),('<eos>', 0) ]
  vocabidx= {}
  for token, freq in vocab.items():
    if freq >= min_freq:
      idx = len(vocablist)
      vocablist.append((token, freq))
      vocabidx[token]=idx
  vocabidx['<unk>']=0
  vocabidx['<pad>']=1
  vocabidx['<cls>']=2
  vocabidx['<eos>']=3
  return vocablist, vocabidx

vocablist_en, vocabidx_en = make_vocab(train_en, 10)
vocablist_vi, vocabidx_vi = make_vocab(train_vi, 10)

#Preprocessing Dataset

def preprocess(data, vocabidx):
  rr=[]
  for tokenlist in data:
    tkl=['<cls>']
    for token in tokenlist:
      tkl.append(token if token in vocabidx else '<unk>')
    tkl.append('<eos>')
    rr.append((tkl))
  return rr

#Print example

train_en_prep = preprocess(train_en, vocabidx_en)
train_vi_prep = preprocess(train_vi, vocabidx_vi)
test_en_prep = preprocess(test_en, vocabidx_en)
for i in range(10):
  print(train_en_prep[i])
  print(train_vi_prep[i])
  print(test_en_prep[i])


train_data = list(zip(train_en_prep, train_vi_prep))
train_data.sort(key = lambda x:(len(x[0]), len(x[1])))
test_data = list(zip(test_en_prep, test_en, test_vi))

#Make batch for train data

def make_batch(data, batchsize):
  bb=[]
  ben=[]
  bvi= []
  for en, vi in data:
    ben.append(en)
    bvi.append(vi)
    if len(ben) >= batchsize:
      bb.append((ben, bvi))
      ben= []
      bvi =[]
  if len(ben) > 0:
    bb.append((ben, bvi))
  return bb
train_data = make_batch(train_data, BATCHSIZE)

#padding for train data

def padding_batch(b):
  maxlen = max([len(x) for x in b])
  for tkl in b:
    for i in range(maxlen - len(tkl)):
      tkl.append('<pad>')

def padding(bb):
  for ben, bvi in bb:
    padding_batch(ben)
    padding_batch(bvi)

padding(train_data)


train_data = [([[vocabidx_en[token] for token in tokenlist] for tokenlist in ben], 
               [[vocabidx_vi[token] for token in tokenlist] for tokenlist in bvi]) for ben, bvi in train_data]
test_data =  [([vocabidx_en[token] for token in enprep], en, vi) for enprep, en, vi in test_data]
# Out:
# ['<cls>', 'Rachel', '<unk>', ':', 'The', 'science', 'behind', 'a', 'climate', 'headline', '<eos>']
# ['<cls>', 'Khoa', 'học', 'đằng', 'sau', 'một', 'tiêu', 'đề', 'về', 'khí', 'hậu', '<eos>']
# ['<cls>', 'When', 'I', 'was', 'little', ',', 'I', 'thought', 'my', 'country', 'was', 'the', 'best', 'on', 'the', 'planet', ',', 'and', 'I', 'grew', 'up', 'singing', 'a', 'song', 'called', '&quot;', 'Nothing', 'To', '<unk>', '.', '&quot;', '<eos>']
# ['<cls>', 'In', '4', 'minutes', ',', 'atmospheric', 'chemist', 'Rachel', '<unk>', 'provides', 'a', 'glimpse', 'of', 'the', 'massive', 'scientific', 'effort', 'behind', 'the', 'bold', 'headlines', 'on', 'climate', 'change', ',', 'with', 'her', 'team', '--', 'one', 'of', 'thousands', 'who', 'contributed', '--', 'taking', 'a', 'risky', 'flight', 'over', 'the', 'rainforest', 'in', 'pursuit', 'of', 'data', 'on', 'a', 'key', 'molecule', '.', '<eos>']
# ['<cls>', 'Trong', '4', 'phút', ',', 'chuyên', 'gia', 'hoá', 'học', 'khí', 'quyển', 'Rachel', '<unk>', 'giới', 'thiệu', 'sơ', 'lược', 'về', 'những', 'nỗ', 'lực', 'khoa', 'học', 'miệt', 'mài', 'đằng', 'sau', 'những', 'tiêu', 'đề', 'táo', 'bạo', 'về', 'biến', 'đổi', 'khí', 'hậu', ',', 'cùng', 'với', 'đoàn', 'nghiên', 'cứu', 'của', 'mình', '--', 'hàng', 'ngàn', 'người', 'đã', 'cống', 'hiến', 'cho', 'dự', 'án', 'này', '--', 'một', 'chuyến', 'bay', 'mạo', 'hiểm', 'qua', 'rừng', 'già', 'để', 'tìm', 'kiếm', 'thông', 'tin', 'về', 'một', 'phân', 'tử', 'then', 'chốt', '.', '<eos>']
# ['<cls>', 'And', 'I', 'was', 'very', 'proud', '.', '<eos>']
# ['<cls>', 'I', '&apos;d', 'like', 'to', 'talk', 'to', 'you', 'today', 'about', 'the', 'scale', 'of', 'the', 'scientific', 'effort', 'that', 'goes', 'into', 'making', 'the', 'headlines', 'you', 'see', 'in', 'the', 'paper', '.', '<eos>']
# ['<cls>', 'Tôi', 'muốn', 'cho', 'các', 'bạn', 'biết', 'về', 'sự', 'to', 'lớn', 'của', 'những', 'nỗ', 'lực', 'khoa', 'học', 'đã', 'góp', 'phần', 'làm', 'nên', 'các', 'dòng', 'tít', 'bạn', 'thường', 'thấy', 'trên', 'báo', '.', '<eos>']
# ['<cls>', 'In', 'school', ',', 'we', 'spent', 'a', 'lot', 'of', 'time', 'studying', 'the', 'history', 'of', 'Kim', '<unk>', ',', 'but', 'we', 'never', 'learned', 'much', 'about', 'the', 'outside', 'world', ',', 'except', 'that', 'America', ',', 'South', 'Korea', ',', 'Japan', 'are', 'the', 'enemies', '.', '<eos>']
# ['<cls>', '<unk>', 'that', 'look', 'like', 'this', 'when', 'they', 'have', 'to', 'do', 'with', 'climate', 'change', ',', 'and', 'headlines', 'that', 'look', 'like', 'this', 'when', 'they', 'have', 'to', 'do', 'with', 'air', 'quality', 'or', '<unk>', '.', '<eos>']
# ['<cls>', 'Có', 'những', 'dòng', 'trông', 'như', 'thế', 'này', 'khi', 'bàn', 'về', 'biến', 'đổi', 'khí', 'hậu', ',', 'và', 'như', 'thế', 'này', 'khi', 'nói', 'về', 'chất', 'lượng', 'không', 'khí', 'hay', 'khói', 'bụi', '.', '<eos>']
# ['<cls>', 'Although', 'I', 'often', 'wondered', 'about', 'the', 'outside', 'world', ',', 'I', 'thought', 'I', 'would', 'spend', 'my', 'entire', 'life', 'in', 'North', 'Korea', ',', 'until', 'everything', 'suddenly', 'changed', '.', '<eos>']
# ['<cls>', 'They', 'are', 'both', 'two', 'branches', 'of', 'the', 'same', 'field', 'of', 'atmospheric', 'science', '.', '<eos>']
# ['<cls>', 'Cả', 'hai', 'đều', 'là', 'một', 'nhánh', 'của', 'cùng', 'một', 'lĩnh', 'vực', 'trong', 'ngành', 'khoa', 'học', 'khí', 'quyển', '.', '<eos>']
# ['<cls>', 'When', 'I', 'was', 'seven', 'years', 'old', ',', 'I', 'saw', 'my', 'first', 'public', 'execution', ',', 'but', 'I', 'thought', 'my', 'life', 'in', 'North', 'Korea', 'was', 'normal', '.', '<eos>']
# ['<cls>', 'Recently', 'the', 'headlines', 'looked', 'like', 'this', 'when', 'the', '<unk>', '<unk>', 'on', 'Climate', '<unk>', ',', 'or', '<unk>', ',', 'put', 'out', 'their', 'report', 'on', 'the', 'state', 'of', 'understanding', 'of', 'the', 'atmospheric', 'system', '.', '<eos>']
# ['<cls>', 'Các', 'tiêu', 'đề', 'gần', 'đây', 'trông', 'như', 'thế', 'này', 'khi', 'Ban', 'Điều', 'hành', 'Biến', 'đổi', 'khí', 'hậu', 'Liên', 'chính', 'phủ', ',', 'gọi', 'tắt', 'là', '<unk>', 'đưa', 'ra', 'bài', 'nghiên', 'cứu', 'của', 'họ', 'về', 'hệ', 'thống', 'khí', 'quyển', '.', '<eos>']
# ['<cls>', 'My', 'family', 'was', 'not', 'poor', ',', 'and', 'myself', ',', 'I', 'had', 'never', 'experienced', 'hunger', '.', '<eos>']
# ['<cls>', 'That', 'report', 'was', 'written', 'by', '<unk>', 'scientists', 'from', '40', 'countries', '.', '<eos>']
# ['<cls>', 'Nghiên', 'cứu', 'được', 'viết', 'bởi', '<unk>', 'nhà', 'khoa', 'học', 'từ', '40', 'quốc', 'gia', 'khác', 'nhau', '.', '<eos>']
# ['<cls>', 'But', 'one', 'day', ',', 'in', '1995', ',', 'my', 'mom', 'brought', 'home', 'a', 'letter', 'from', 'a', '<unk>', '&apos;s', 'sister', '.', '<eos>']
# ['<cls>', 'They', 'wrote', 'almost', 'a', 'thousand', 'pages', 'on', 'the', 'topic', '.', '<eos>']
# ['<cls>', 'Họ', 'viết', 'gần', '1000', 'trang', 'về', 'chủ', 'đề', 'này', '.', '<eos>']
# ['<cls>', 'It', 'read', ',', '&quot;', 'When', 'you', 'read', 'this', ',', 'all', 'five', 'family', 'members', 'will', 'not', 'exist', 'in', 'this', 'world', ',', 'because', 'we', 'haven', '&apos;t', 'eaten', 'for', 'the', 'past', 'two', 'weeks', '.', '<eos>']
# ['<cls>', 'And', 'all', 'of', 'those', 'pages', 'were', 'reviewed', 'by', 'another', '<unk>', 'scientists', 'and', '<unk>', ',', 'from', '<unk>', 'countries', '.', '<eos>']
# ['<cls>', 'Và', 'tất', 'cả', 'các', 'trang', 'đều', 'được', 'xem', 'xét', 'bởi', '400', 'khoa', 'học', 'gia', 'và', 'nhà', 'phê', 'bình', 'khác', 'từ', '<unk>', 'quốc', 'gia', '.', '<eos>']
# ['<cls>', 'We', 'are', 'lying', 'on', 'the', 'floor', 'together', ',', 'and', 'our', 'bodies', 'are', 'so', 'weak', 'we', 'are', 'ready', 'to', 'die', '.', '&quot;', '<eos>']
# ['<cls>', 'It', '&apos;s', 'a', 'big', 'community', '.', 'It', '&apos;s', 'such', 'a', 'big', 'community', ',', 'in', 'fact', ',', 'that', 'our', 'annual', 'gathering', 'is', 'the', 'largest', 'scientific', 'meeting', 'in', 'the', 'world', '.', '<eos>']
# ['<cls>', 'Đó', 'là', 'cả', 'một', 'cộng', 'đồng', 'lớn', ',', 'lớn', 'đến', 'nỗi', 'trên', 'thực', 'tế', 'cuộc', 'tụ', 'hội', 'hằng', 'năm', 'của', 'chúng', 'tôi', 'là', 'hội', 'nghị', 'khoa', 'học', '&#91;', 'tự', 'nhiên', '&#93;', 'lớn', 'nhất', 'thế', 'giới', '.', '<eos>']
# ['<cls>', 'I', 'was', 'so', 'shocked', '.', '<eos>']

# %%
class BiLSTMEncDec(torch.nn.Module):
    def __init__(self,vocablist_x,vocabidx_x,vocablist_y,vocabidx_y):
        super(BiLSTMEncDec,self).__init__()

        #Bidirection LSTM with Encoder and Decoder
        self.encemb = torch.nn.Embedding(len(vocablist_x),256, padding_idx=vocabidx_x['<pad>'])

        self.dropout = torch.nn.Dropout(0.5)

        self.encrnn = torch.nn.LSTM(256,516,2,dropout = 0.5,  bidirectional=True)

        self.decemb = torch.nn.Embedding(len(vocablist_x),256, padding_idx=vocabidx_y['<pad>'])

        self.decrnn = torch.nn.LSTM(256,516,2,dropout = 0.5, bidirectional=True)

        self.decout = torch.nn.Linear(516*2,len(vocabidx_y))

    def forward(self,x):
        #encoder
        #x: input
        #y:output
        x,y = x[0],x[1]
        e_x = self.encemb(x)
        n_x = e_x.size()[0]
        h = torch.zeros((4,x.size(1),516), dtype=torch.float32).to(DEVICE)
        c = torch.zeros((4,x.size(1),516), dtype=torch.float32).to(DEVICE)
        for i in range(n_x):
            output,(h,c)=self.encrnn(torch.unsqueeze(e_x[i],0),(h,c)) 
        output = torch.squeeze(output)
        #decoder
        e_y = self.decemb(y)

        n_y = e_y.size()[0]
        loss = torch.tensor(0.,dtype=torch.float32).to(DEVICE)
        for i in range(n_y-1):
            out,(h,c) = self.decrnn(torch.unsqueeze(e_y[i],0),(h,c))
            out = torch.squeeze(out)
            loss += F.cross_entropy(self.decout(out), y[i+1])
        return loss

    def evaluate(self,x,vocablist_y,vocabidx_y):
        # encoder

        e_x = self.encemb(x)
        n_x = e_x.size()[0]

        h = torch.zeros((4,x.size(1),516), dtype=torch.float32).to(DEVICE)
        c = torch.zeros((4,x.size(1),516), dtype=torch.float32).to(DEVICE)
        for i in range(n_x):
            output,(h,c)=self.encrnn(torch.unsqueeze(e_x[i],0),(h,c))
        # decoder

        y = torch.tensor([vocabidx_y['<cls>']]).to(DEVICE)
        e_y = self.decemb(y)
        pred = []
        for i in range(30):
            out,(h,c) = self.decrnn(torch.unsqueeze(e_y,0),(h,c))
            out = out.view(1,1032)
            pred_id = self.decout(out).squeeze().argmax()
            #pred_id predicts the output word ID, if pred_id is equal to the ID of <eos> inference ends.
            if pred_id == vocabidx_y['<eos>']:
                break
            pred_y = vocablist_y[pred_id][0]
            pred.append(pred_y)
            #The decoder processes 1 word by word and takes the resulting output as the next input
            y[0] = pred_id
            e_y = self.decemb(y)
        return pred

# %%
list_train = []
list_loss = []
def train():
    model = BiLSTMEncDec(vocablist_en,vocabidx_en,vocablist_vi,vocabidx_vi).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr = LR)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.8)
    for epoch in range(EPOCH):
        loss = 0
        step = 0
        for ben, bvi in train_data:
            ben = torch.tensor(ben,dtype=torch.int64).transpose(0,1).to(DEVICE)
            bvi = torch.tensor(bvi,dtype=torch.int64).transpose(0,1).to(DEVICE)
            optimizer.zero_grad()
            batchloss =model((ben,bvi))
            batchloss.backward()
            optimizer.step()
            loss = loss + batchloss.item()
            if step %100 == 0:
                print('step:',step,'batchloss:',batchloss.item())
            step+=1
        print('epoch',epoch,': loss',loss)
        list_loss.append(loss)
        if (epoch%2==0):
            torch.save(model.state_dict(),MODELNAME)
            list_train.append(test_during_train(epoch))
        scheduler.step()
    torch.save(model.state_dict(),MODELNAME)

def test_during_train(epoch):
    total = 0
    correct = 0
    model = BiLSTMEncDec(vocablist_en,vocabidx_en,vocablist_vi,vocabidx_vi).to(DEVICE)
    model.load_state_dict(torch.load(MODELNAME))
    model.eval()
    ref = []
    pred =[]
    for enprep, en, vi in test_data:
        input =  torch.tensor([enprep], dtype=torch.int64).transpose(0,1).to(DEVICE)
        p = model.evaluate(input, vocablist_vi,vocabidx_vi)
        ref.append([vi])
        pred.append(p)
    bleu = torchtext.data.metrics.bleu_score(pred,ref)
    print('bleu of epoch {}: '.format(epoch),bleu)
    return bleu

# %% [markdown]
# Training

# %%
EPOCH = 10
LR = 0.001
MODELNAME ='iwslt15-en-vi-lstm-lr-0.001.model'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

import time
start = time.time()
train()
print("Done at:", time.time()-start)
# Out:
# step: 0 batchloss: 8.566254615783691
# step: 100 batchloss: 25.310598373413086
# step: 200 batchloss: 31.356935501098633
# step: 300 batchloss: 51.43785095214844
# step: 400 batchloss: 45.19828796386719
# step: 500 batchloss: 35.16333770751953
# step: 600 batchloss: 51.88880157470703
# step: 700 batchloss: 43.972068786621094
# step: 800 batchloss: 59.01970672607422
# step: 900 batchloss: 46.668128967285156
# step: 1000 batchloss: 60.2830924987793
# step: 1100 batchloss: 45.3815803527832
# step: 1200 batchloss: 62.09601974487305
# step: 1300 batchloss: 52.25365447998047
# step: 1400 batchloss: 63.21088409423828
# step: 1500 batchloss: 54.49907684326172
# step: 1600 batchloss: 87.90258026123047
# step: 1700 batchloss: 66.7521743774414
# step: 1800 batchloss: 58.169586181640625
# step: 1900 batchloss: 77.09764862060547
# step: 2000 batchloss: 74.25008392333984
# step: 2100 batchloss: 64.33557891845703
# step: 2200 batchloss: 82.91483306884766
# step: 2300 batchloss: 84.86637115478516
# step: 2400 batchloss: 84.03901672363281
# step: 2500 batchloss: 79.06884002685547
# step: 2600 batchloss: 139.8470916748047
# step: 2700 batchloss: 119.71244049072266
# step: 2800 batchloss: 111.35228729248047
# step: 2900 batchloss: 122.07429504394531
# step: 3000 batchloss: 93.4762954711914
# step: 3100 batchloss: 104.50177001953125
# step: 3200 batchloss: 128.08575439453125
# step: 3300 batchloss: 161.32656860351562
# step: 3400 batchloss: 138.98541259765625
# step: 3500 batchloss: 142.2554168701172
# step: 3600 batchloss: 161.3802032470703
# step: 3700 batchloss: 158.73614501953125
# step: 3800 batchloss: 179.26345825195312
# step: 3900 batchloss: 214.0040283203125
# step: 4000 batchloss: 202.8383026123047
# step: 4100 batchloss: 322.22467041015625
# epoch 0 : loss 414475.61582040787
# bleu of epoch 0:  0.04615623876452446
# step: 0 batchloss: 6.914051532745361
# step: 100 batchloss: 14.922602653503418
# step: 200 batchloss: 18.935747146606445
# step: 300 batchloss: 30.03660774230957
# step: 400 batchloss: 28.954479217529297
# step: 500 batchloss: 24.26241111755371
# step: 600 batchloss: 33.708587646484375
# step: 700 batchloss: 30.660888671875
# step: 800 batchloss: 38.608306884765625
# step: 900 batchloss: 34.123722076416016
# step: 1000 batchloss: 43.26773452758789
# step: 1100 batchloss: 32.6602897644043
# step: 1200 batchloss: 44.54616928100586
# step: 1300 batchloss: 37.736934661865234
# step: 1400 batchloss: 47.10969543457031
# step: 1500 batchloss: 41.5007209777832
# step: 1600 batchloss: 69.9610366821289
# step: 1700 batchloss: 51.584346771240234
# step: 1800 batchloss: 47.129005432128906
# step: 1900 batchloss: 61.17401123046875
# step: 2000 batchloss: 59.672767639160156
# step: 2100 batchloss: 52.82722473144531
# step: 2200 batchloss: 68.41500091552734
# step: 2300 batchloss: 68.77395629882812
# step: 2400 batchloss: 68.0162353515625
# step: 2500 batchloss: 66.91297912597656
# step: 2600 batchloss: 120.50557708740234
# step: 2700 batchloss: 102.93093872070312
# step: 2800 batchloss: 97.19775390625
# step: 2900 batchloss: 105.50104522705078
# step: 3000 batchloss: 82.19597625732422
# step: 3100 batchloss: 89.00559997558594
# step: 3200 batchloss: 108.70992279052734
# step: 3300 batchloss: 142.6826934814453
# step: 3400 batchloss: 121.40638732910156
# step: 3500 batchloss: 124.80266571044922
# step: 3600 batchloss: 144.127197265625
# step: 3700 batchloss: 139.44302368164062
# step: 3800 batchloss: 161.05247497558594
# step: 3900 batchloss: 194.92575073242188
# step: 4000 batchloss: 186.7906036376953
# step: 4100 batchloss: 296.32037353515625
# epoch 1 : loss 345730.389952898
# step: 0 batchloss: 1.5071955919265747
# step: 100 batchloss: 13.057186126708984
# step: 200 batchloss: 15.232465744018555
# step: 300 batchloss: 25.592592239379883
# step: 400 batchloss: 24.765100479125977
# step: 500 batchloss: 21.774280548095703
# step: 600 batchloss: 28.528087615966797
# step: 700 batchloss: 26.681407928466797
# step: 800 batchloss: 34.41259002685547
# step: 900 batchloss: 29.11936378479004
# step: 1000 batchloss: 37.69070053100586
# step: 1100 batchloss: 27.790332794189453
# step: 1200 batchloss: 38.863277435302734
# step: 1300 batchloss: 32.24635696411133
# step: 1400 batchloss: 41.092430114746094
# step: 1500 batchloss: 36.15300750732422
# step: 1600 batchloss: 62.14219665527344
# step: 1700 batchloss: 45.85150909423828
# step: 1800 batchloss: 42.64084243774414
# step: 1900 batchloss: 55.14636993408203
# step: 2000 batchloss: 52.78080749511719
# step: 2100 batchloss: 47.74414825439453
# step: 2200 batchloss: 62.8021354675293
# step: 2300 batchloss: 62.761863708496094
# step: 2400 batchloss: 61.20576858520508
# step: 2500 batchloss: 60.19495391845703
# step: 2600 batchloss: 111.23544311523438
# step: 2700 batchloss: 95.24668884277344
# step: 2800 batchloss: 89.4058609008789
# step: 2900 batchloss: 94.91592407226562
# step: 3000 batchloss: 75.76676177978516
# step: 3100 batchloss: 82.4025650024414
# step: 3200 batchloss: 99.44813537597656
# step: 3300 batchloss: 133.4197235107422
# step: 3400 batchloss: 111.19092559814453
# step: 3500 batchloss: 114.30718994140625
# step: 3600 batchloss: 136.21446228027344
# step: 3700 batchloss: 128.57901000976562
# step: 3800 batchloss: 151.91844177246094
# step: 3900 batchloss: 183.70640563964844
# step: 4000 batchloss: 175.09877014160156
# step: 4100 batchloss: 280.1405334472656
# epoch 2 : loss 316789.8455159664
# bleu of epoch 2:  0.07411557562707623
# step: 0 batchloss: 0.17141762375831604
# step: 100 batchloss: 12.709277153015137
# step: 200 batchloss: 13.9517183303833
# step: 300 batchloss: 24.626876831054688
# step: 400 batchloss: 22.362165451049805
# step: 500 batchloss: 20.1925106048584
# step: 600 batchloss: 26.22172737121582
# step: 700 batchloss: 24.45757293701172
# step: 800 batchloss: 30.1623477935791
# step: 900 batchloss: 25.905000686645508
# step: 1000 batchloss: 34.675254821777344
# step: 1100 batchloss: 24.944557189941406
# step: 1200 batchloss: 36.006099700927734
# step: 1300 batchloss: 29.567962646484375
# step: 1400 batchloss: 38.728614807128906
# step: 1500 batchloss: 33.413490295410156
# step: 1600 batchloss: 57.27286148071289
# step: 1700 batchloss: 41.22648620605469
# step: 1800 batchloss: 39.200801849365234
# step: 1900 batchloss: 50.8494987487793
# step: 2000 batchloss: 48.73271560668945
# step: 2100 batchloss: 44.61183166503906
# step: 2200 batchloss: 58.670684814453125
# step: 2300 batchloss: 57.00649642944336
# step: 2400 batchloss: 56.53799819946289
# step: 2500 batchloss: 56.26161575317383
# step: 2600 batchloss: 105.91793060302734
# step: 2700 batchloss: 88.8132553100586
# step: 2800 batchloss: 85.19147491455078
# step: 2900 batchloss: 90.12379455566406
# step: 3000 batchloss: 68.93914794921875
# step: 3100 batchloss: 78.0509262084961
# step: 3200 batchloss: 92.97344970703125
# step: 3300 batchloss: 127.53785705566406
# step: 3400 batchloss: 107.39582061767578
# step: 3500 batchloss: 109.39655303955078
# step: 3600 batchloss: 128.7253875732422
# step: 3700 batchloss: 124.48909759521484
# step: 3800 batchloss: 144.90924072265625
# step: 3900 batchloss: 174.17640686035156
# step: 4000 batchloss: 165.89999389648438
# step: 4100 batchloss: 270.3933410644531
# epoch 3 : loss 298302.49255891144
# step: 0 batchloss: 0.2665025293827057
# step: 100 batchloss: 12.167197227478027
# step: 200 batchloss: 13.116340637207031
# step: 300 batchloss: 24.021709442138672
# step: 400 batchloss: 20.878719329833984
# step: 500 batchloss: 18.60674285888672
# step: 600 batchloss: 23.978607177734375
# step: 700 batchloss: 23.673507690429688
# step: 800 batchloss: 29.14724349975586
# step: 900 batchloss: 24.124347686767578
# step: 1000 batchloss: 33.51336669921875
# step: 1100 batchloss: 24.06961441040039
# step: 1200 batchloss: 33.39510726928711
# step: 1300 batchloss: 27.984941482543945
# step: 1400 batchloss: 36.38713073730469
# step: 1500 batchloss: 29.793800354003906
# step: 1600 batchloss: 53.1804313659668
# step: 1700 batchloss: 39.030799865722656
# step: 1800 batchloss: 37.192718505859375
# step: 1900 batchloss: 47.15849304199219
# step: 2000 batchloss: 45.79246139526367
# step: 2100 batchloss: 42.764156341552734
# step: 2200 batchloss: 53.98488235473633
# step: 2300 batchloss: 52.80479431152344
# step: 2400 batchloss: 52.946075439453125
# step: 2500 batchloss: 52.589202880859375
# step: 2600 batchloss: 101.91716766357422
# step: 2700 batchloss: 84.25009155273438
# step: 2800 batchloss: 81.38328552246094
# step: 2900 batchloss: 85.2094497680664
# step: 3000 batchloss: 66.12615203857422
# step: 3100 batchloss: 73.30104064941406
# step: 3200 batchloss: 87.49983978271484
# step: 3300 batchloss: 121.20232391357422
# step: 3400 batchloss: 103.19046020507812
# step: 3500 batchloss: 103.63909912109375
# step: 3600 batchloss: 124.0978012084961
# step: 3700 batchloss: 120.02725219726562
# step: 3800 batchloss: 139.9248046875
# step: 3900 batchloss: 168.5220947265625
# step: 4000 batchloss: 164.24661254882812
# step: 4100 batchloss: 263.067138671875
# epoch 4 : loss 286562.898809582
# bleu of epoch 4:  0.08521123740019307
# step: 0 batchloss: 0.19392794370651245
# step: 100 batchloss: 11.085280418395996
# step: 200 batchloss: 12.4683198928833
# step: 300 batchloss: 23.014877319335938
# step: 400 batchloss: 20.346298217773438
# step: 500 batchloss: 18.064315795898438
# step: 600 batchloss: 23.161352157592773
# step: 700 batchloss: 22.503122329711914
# step: 800 batchloss: 27.91371726989746
# step: 900 batchloss: 23.266408920288086
# step: 1000 batchloss: 31.764385223388672
# step: 1100 batchloss: 23.29070281982422
# step: 1200 batchloss: 32.2696647644043
# step: 1300 batchloss: 27.066308975219727
# step: 1400 batchloss: 34.38410186767578
# step: 1500 batchloss: 29.335590362548828
# step: 1600 batchloss: 51.06047821044922
# step: 1700 batchloss: 37.94219207763672
# step: 1800 batchloss: 34.34320068359375
# step: 1900 batchloss: 45.295616149902344
# step: 2000 batchloss: 41.91665267944336
# step: 2100 batchloss: 39.8290901184082
# step: 2200 batchloss: 52.771087646484375
# step: 2300 batchloss: 49.478675842285156
# step: 2400 batchloss: 49.55263900756836
# step: 2500 batchloss: 49.1579704284668
# step: 2600 batchloss: 95.66014099121094
# step: 2700 batchloss: 79.33744049072266
# step: 2800 batchloss: 77.5291519165039
# step: 2900 batchloss: 80.1647720336914
# step: 3000 batchloss: 60.977516174316406
# step: 3100 batchloss: 69.22563934326172
# step: 3200 batchloss: 81.8402328491211
# step: 3300 batchloss: 113.74974822998047
# step: 3400 batchloss: 95.8406982421875
# step: 3500 batchloss: 97.93594360351562
# step: 3600 batchloss: 116.62481689453125
# step: 3700 batchloss: 108.77030944824219
# step: 3800 batchloss: 133.18177795410156
# step: 3900 batchloss: 159.80506896972656
# step: 4000 batchloss: 156.03309631347656
# step: 4100 batchloss: 252.3919219970703
# epoch 5 : loss 269113.84447169304
# step: 0 batchloss: 0.125274658203125
# step: 100 batchloss: 10.813284873962402
# step: 200 batchloss: 11.83736801147461
# step: 300 batchloss: 22.336347579956055
# step: 400 batchloss: 19.566476821899414
# step: 500 batchloss: 17.572500228881836
# step: 600 batchloss: 21.223970413208008
# step: 700 batchloss: 21.256406784057617
# step: 800 batchloss: 26.59117317199707
# step: 900 batchloss: 21.445865631103516
# step: 1000 batchloss: 30.19648551940918
# step: 1100 batchloss: 21.34243392944336
# step: 1200 batchloss: 30.737428665161133
# step: 1300 batchloss: 24.780166625976562
# step: 1400 batchloss: 33.390830993652344
# step: 1500 batchloss: 27.246965408325195
# step: 1600 batchloss: 48.54764938354492
# step: 1700 batchloss: 35.071983337402344
# step: 1800 batchloss: 32.23097229003906
# step: 1900 batchloss: 41.69468688964844
# step: 2000 batchloss: 40.178462982177734
# step: 2100 batchloss: 38.39787292480469
# step: 2200 batchloss: 48.969581604003906
# step: 2300 batchloss: 46.796051025390625
# step: 2400 batchloss: 48.56431579589844
# step: 2500 batchloss: 47.47331619262695
# step: 2600 batchloss: 89.5360336303711
# step: 2700 batchloss: 77.11114501953125
# step: 2800 batchloss: 74.81258392333984
# step: 2900 batchloss: 75.9302749633789
# step: 3000 batchloss: 59.78920364379883
# step: 3100 batchloss: 66.7947998046875
# step: 3200 batchloss: 81.05558776855469
# step: 3300 batchloss: 111.2293930053711
# step: 3400 batchloss: 93.65162658691406
# step: 3500 batchloss: 95.29627990722656
# step: 3600 batchloss: 115.35377502441406
# step: 3700 batchloss: 105.84457397460938
# step: 3800 batchloss: 128.97354125976562
# step: 3900 batchloss: 155.6903839111328
# step: 4000 batchloss: 152.9024658203125
# step: 4100 batchloss: 247.04843139648438
# epoch 6 : loss 260093.2430282086
# bleu of epoch 6:  0.09083898880482763
# step: 0 batchloss: 0.18984337151050568
# step: 100 batchloss: 10.300289154052734
# step: 200 batchloss: 10.870826721191406
# step: 300 batchloss: 21.64937973022461
# step: 400 batchloss: 18.481245040893555
# step: 500 batchloss: 16.698312759399414
# step: 600 batchloss: 20.04073715209961
# step: 700 batchloss: 20.74864387512207
# step: 800 batchloss: 25.34632110595703
# step: 900 batchloss: 21.47903060913086
# step: 1000 batchloss: 29.762388229370117
# step: 1100 batchloss: 21.29208755493164
# step: 1200 batchloss: 30.616588592529297
# step: 1300 batchloss: 24.858734130859375
# step: 1400 batchloss: 31.587011337280273
# step: 1500 batchloss: 26.241960525512695
# step: 1600 batchloss: 47.50357437133789
# step: 1700 batchloss: 33.287166595458984
# step: 1800 batchloss: 33.03411102294922
# step: 1900 batchloss: 40.45924377441406
# step: 2000 batchloss: 38.87924575805664
# step: 2100 batchloss: 36.11347961425781
# step: 2200 batchloss: 47.19034957885742
# step: 2300 batchloss: 45.37595748901367
# step: 2400 batchloss: 44.8267936706543
# step: 2500 batchloss: 46.4171257019043
# step: 2600 batchloss: 89.6926498413086
# step: 2700 batchloss: 74.36531066894531
# step: 2800 batchloss: 72.2263412475586
# step: 2900 batchloss: 74.86749267578125
# step: 3000 batchloss: 56.74034881591797
# step: 3100 batchloss: 66.48558044433594
# step: 3200 batchloss: 78.60709381103516
# step: 3300 batchloss: 108.01275634765625
# step: 3400 batchloss: 90.334716796875
# step: 3500 batchloss: 92.08673095703125
# step: 3600 batchloss: 111.98423767089844
# step: 3700 batchloss: 103.43994140625
# step: 3800 batchloss: 127.15966033935547
# step: 3900 batchloss: 155.29139709472656
# step: 4000 batchloss: 150.7906036376953
# step: 4100 batchloss: 242.7715606689453
# epoch 7 : loss 253489.95642343163
# step: 0 batchloss: 0.24969074130058289
# step: 100 batchloss: 10.255796432495117
# step: 200 batchloss: 11.083999633789062
# step: 300 batchloss: 21.045942306518555
# step: 400 batchloss: 17.38648796081543
# step: 500 batchloss: 16.07097625732422
# step: 600 batchloss: 19.683094024658203
# step: 700 batchloss: 19.15120506286621
# step: 800 batchloss: 25.08444595336914
# step: 900 batchloss: 20.111309051513672
# step: 1000 batchloss: 27.438859939575195
# step: 1100 batchloss: 20.762136459350586
# step: 1200 batchloss: 29.201581954956055
# step: 1300 batchloss: 23.352771759033203
# step: 1400 batchloss: 30.349998474121094
# step: 1500 batchloss: 25.26537322998047
# step: 1600 batchloss: 44.78565216064453
# step: 1700 batchloss: 32.56620788574219
# step: 1800 batchloss: 30.26352310180664
# step: 1900 batchloss: 39.39780044555664
# step: 2000 batchloss: 36.95304870605469
# step: 2100 batchloss: 36.28728485107422
# step: 2200 batchloss: 45.570709228515625
# step: 2300 batchloss: 44.29887390136719
# step: 2400 batchloss: 44.404178619384766
# step: 2500 batchloss: 44.107269287109375
# step: 2600 batchloss: 87.79085540771484
# step: 2700 batchloss: 73.36053466796875
# step: 2800 batchloss: 71.0852279663086
# step: 2900 batchloss: 74.07051849365234
# step: 3000 batchloss: 56.370670318603516
# step: 3100 batchloss: 65.26094818115234
# step: 3200 batchloss: 76.25482940673828
# step: 3300 batchloss: 107.47747039794922
# step: 3400 batchloss: 88.09213256835938
# step: 3500 batchloss: 91.0354995727539
# step: 3600 batchloss: 110.35118103027344
# step: 3700 batchloss: 102.6651611328125
# step: 3800 batchloss: 123.53204345703125
# step: 3900 batchloss: 150.63247680664062
# step: 4000 batchloss: 148.04544067382812
# step: 4100 batchloss: 241.51644897460938
# epoch 8 : loss 247639.4598430544
# bleu of epoch 8:  0.09259629016439151
# step: 0 batchloss: 0.0898066833615303
# step: 100 batchloss: 9.691834449768066
# step: 200 batchloss: 10.873361587524414
# step: 300 batchloss: 20.785743713378906
# step: 400 batchloss: 17.925527572631836
# step: 500 batchloss: 15.490240097045898
# step: 600 batchloss: 19.43861198425293
# step: 700 batchloss: 20.01193618774414
# step: 800 batchloss: 24.280071258544922
# step: 900 batchloss: 19.704322814941406
# step: 1000 batchloss: 27.116300582885742
# step: 1100 batchloss: 19.594852447509766
# step: 1200 batchloss: 28.31315040588379
# step: 1300 batchloss: 23.22953987121582
# step: 1400 batchloss: 29.4834041595459
# step: 1500 batchloss: 25.376625061035156
# step: 1600 batchloss: 43.243812561035156
# step: 1700 batchloss: 31.57750129699707
# step: 1800 batchloss: 30.24810218811035
# step: 1900 batchloss: 39.17945861816406
# step: 2000 batchloss: 35.202613830566406
# step: 2100 batchloss: 33.97346496582031
# step: 2200 batchloss: 43.8890495300293
# step: 2300 batchloss: 43.441104888916016
# step: 2400 batchloss: 41.979122161865234
# step: 2500 batchloss: 43.46756362915039
# step: 2600 batchloss: 85.39521026611328
# step: 2700 batchloss: 72.1153564453125
# step: 2800 batchloss: 69.5570068359375
# step: 2900 batchloss: 72.03205108642578
# step: 3000 batchloss: 54.58489990234375
# step: 3100 batchloss: 63.309783935546875
# step: 3200 batchloss: 75.0127182006836
# step: 3300 batchloss: 104.15721893310547
# step: 3400 batchloss: 86.98963165283203
# step: 3500 batchloss: 88.7481918334961
# step: 3600 batchloss: 108.4645767211914
# step: 3700 batchloss: 100.0077896118164
# step: 3800 batchloss: 122.36630249023438
# step: 3900 batchloss: 148.0074005126953
# step: 4000 batchloss: 145.6017303466797
# step: 4100 batchloss: 235.21267700195312
# epoch 9 : loss 242404.3674305156
# step: 0 batchloss: 0.1470697969198227
# step: 100 batchloss: 9.42261791229248
# step: 200 batchloss: 10.768732070922852
# step: 300 batchloss: 20.74872398376465
# step: 400 batchloss: 16.862594604492188
# step: 500 batchloss: 15.05994987487793
# step: 600 batchloss: 18.896041870117188
# step: 700 batchloss: 18.739221572875977
# step: 800 batchloss: 23.523983001708984
# step: 900 batchloss: 19.13257598876953
# step: 1000 batchloss: 26.328020095825195
# step: 1100 batchloss: 19.015859603881836
# step: 1200 batchloss: 27.177387237548828
# step: 1300 batchloss: 22.110727310180664
# step: 1400 batchloss: 29.761585235595703
# step: 1500 batchloss: 23.369171142578125
# step: 1600 batchloss: 42.045814514160156
# step: 1700 batchloss: 28.79371452331543
# step: 1800 batchloss: 28.208276748657227
# step: 1900 batchloss: 37.21774673461914
# step: 2000 batchloss: 34.829898834228516
# step: 2100 batchloss: 33.81898880004883
# step: 2200 batchloss: 42.57537841796875
# step: 2300 batchloss: 41.154048919677734
# step: 2400 batchloss: 40.57701873779297
# step: 2500 batchloss: 41.428497314453125
# step: 2600 batchloss: 82.37079620361328
# step: 2700 batchloss: 67.99234771728516
# step: 2800 batchloss: 67.0216064453125
# step: 2900 batchloss: 65.93975067138672
# step: 3000 batchloss: 52.058074951171875
# step: 3100 batchloss: 59.27900314331055
# step: 3200 batchloss: 72.29446411132812
# step: 3300 batchloss: 99.90267181396484
# step: 3400 batchloss: 82.59196472167969
# step: 3500 batchloss: 86.09410095214844
# step: 3600 batchloss: 104.65699768066406
# step: 3700 batchloss: 95.59663391113281
# step: 3800 batchloss: 117.61270141601562
# step: 3900 batchloss: 143.1566925048828
# step: 4000 batchloss: 139.93922424316406
# step: 4100 batchloss: 230.32225036621094
# epoch 10 : loss 232714.7365450859
# bleu of epoch 10:  0.0912042809633812
# step: 0 batchloss: 0.2098217010498047
# step: 100 batchloss: 9.154027938842773
# step: 200 batchloss: 10.403909683227539
# step: 300 batchloss: 21.22648048400879
# step: 400 batchloss: 16.75516128540039
# step: 500 batchloss: 14.715967178344727
# step: 600 batchloss: 18.35780906677246
# step: 700 batchloss: 18.455698013305664
# step: 800 batchloss: 22.505884170532227
# step: 900 batchloss: 18.691129684448242
# step: 1000 batchloss: 24.75418472290039
# step: 1100 batchloss: 18.301057815551758
# step: 1200 batchloss: 26.655527114868164
# step: 1300 batchloss: 20.773479461669922
# step: 1400 batchloss: 27.787220001220703
# step: 1500 batchloss: 22.603792190551758
# step: 1600 batchloss: 40.94147872924805
# step: 1700 batchloss: 28.75868797302246
# step: 1800 batchloss: 27.443872451782227
# step: 1900 batchloss: 37.85409164428711
# step: 2000 batchloss: 32.5550537109375
# step: 2100 batchloss: 31.172908782958984
# step: 2200 batchloss: 42.039920806884766
# step: 2300 batchloss: 38.31623840332031
# step: 2400 batchloss: 38.91462326049805
# step: 2500 batchloss: 40.1858024597168
# step: 2600 batchloss: 79.69852447509766
# step: 2700 batchloss: 66.38130187988281
# step: 2800 batchloss: 65.1563491821289
# step: 2900 batchloss: 65.35092163085938
# step: 3000 batchloss: 50.536766052246094
# step: 3100 batchloss: 57.9403190612793
# step: 3200 batchloss: 69.72333526611328
# step: 3300 batchloss: 97.54341888427734
# step: 3400 batchloss: 81.51586151123047
# step: 3500 batchloss: 83.52645111083984
# step: 3600 batchloss: 102.76853942871094
# step: 3700 batchloss: 93.69965362548828
# step: 3800 batchloss: 116.08000183105469
# step: 3900 batchloss: 140.64154052734375
# step: 4000 batchloss: 138.5188446044922
# step: 4100 batchloss: 224.63558959960938
# epoch 11 : loss 227000.67089495063
# step: 0 batchloss: 0.18695257604122162
# step: 100 batchloss: 9.038969039916992
# step: 200 batchloss: 9.569615364074707
# step: 300 batchloss: 19.7668399810791
# step: 400 batchloss: 16.529415130615234
# step: 500 batchloss: 13.503211975097656
# step: 600 batchloss: 17.723318099975586
# step: 700 batchloss: 17.630033493041992
# step: 800 batchloss: 22.210081100463867
# step: 900 batchloss: 17.598405838012695
# step: 1000 batchloss: 23.53226089477539
# step: 1100 batchloss: 18.491992950439453
# step: 1200 batchloss: 25.61028289794922
# step: 1300 batchloss: 20.36351776123047
# step: 1400 batchloss: 27.546411514282227
# step: 1500 batchloss: 22.406715393066406
# step: 1600 batchloss: 38.82366943359375
# step: 1700 batchloss: 27.746023178100586
# step: 1800 batchloss: 27.263044357299805
# step: 1900 batchloss: 35.53836441040039
# step: 2000 batchloss: 32.74481964111328
# step: 2100 batchloss: 31.649639129638672
# step: 2200 batchloss: 42.11293411254883
# step: 2300 batchloss: 38.80760192871094
# step: 2400 batchloss: 38.174049377441406
# step: 2500 batchloss: 39.116329193115234
# step: 2600 batchloss: 75.91509246826172
# step: 2700 batchloss: 65.14552307128906
# step: 2800 batchloss: 63.472530364990234
# step: 2900 batchloss: 65.20646667480469
# step: 3000 batchloss: 48.52326202392578
# step: 3100 batchloss: 58.801361083984375
# step: 3200 batchloss: 67.2032699584961
# step: 3300 batchloss: 97.8116455078125
# step: 3400 batchloss: 80.17325592041016
# step: 3500 batchloss: 82.82099151611328
# step: 3600 batchloss: 100.40974426269531
# step: 3700 batchloss: 93.8783950805664
# step: 3800 batchloss: 116.19596862792969
# step: 3900 batchloss: 140.45440673828125
# step: 4000 batchloss: 137.16531372070312
# step: 4100 batchloss: 223.36570739746094
# epoch 12 : loss 222658.57959143817
# bleu of epoch 12:  0.09482549106830357
# step: 0 batchloss: 0.19019046425819397
# step: 100 batchloss: 8.829957008361816
# step: 200 batchloss: 9.339860916137695
# step: 300 batchloss: 19.33140754699707
# step: 400 batchloss: 16.2385196685791
# step: 500 batchloss: 13.717719078063965
# step: 600 batchloss: 16.653160095214844
# step: 700 batchloss: 17.009057998657227
# step: 800 batchloss: 21.77674674987793
# step: 900 batchloss: 17.3512020111084
# step: 1000 batchloss: 22.64533805847168
# step: 1100 batchloss: 17.750572204589844
# step: 1200 batchloss: 25.3109188079834
# step: 1300 batchloss: 20.417692184448242
# step: 1400 batchloss: 26.233551025390625
# step: 1500 batchloss: 21.292390823364258
# step: 1600 batchloss: 39.59716796875
# step: 1700 batchloss: 27.782238006591797
# step: 1800 batchloss: 27.473392486572266
# step: 1900 batchloss: 33.73418426513672
# step: 2000 batchloss: 31.627267837524414
# step: 2100 batchloss: 30.433870315551758
# step: 2200 batchloss: 39.70002365112305
# step: 2300 batchloss: 38.248355865478516
# step: 2400 batchloss: 37.80783462524414
# step: 2500 batchloss: 39.449737548828125
# step: 2600 batchloss: 75.99671173095703
# step: 2700 batchloss: 61.97404861450195
# step: 2800 batchloss: 62.8753547668457
# step: 2900 batchloss: 61.80183410644531
# step: 3000 batchloss: 49.34444808959961
# step: 3100 batchloss: 56.51683044433594
# step: 3200 batchloss: 67.23617553710938
# step: 3300 batchloss: 93.73699188232422
# step: 3400 batchloss: 78.1512451171875
# step: 3500 batchloss: 80.0553207397461
# step: 3600 batchloss: 98.75370788574219
# step: 3700 batchloss: 89.68052673339844
# step: 3800 batchloss: 110.91632080078125
# step: 3900 batchloss: 140.14646911621094
# step: 4000 batchloss: 135.3997039794922
# step: 4100 batchloss: 222.08363342285156
# epoch 13 : loss 218947.68687438965
# step: 0 batchloss: 0.22613996267318726
# step: 100 batchloss: 8.845967292785645
# step: 200 batchloss: 9.188288688659668
# step: 300 batchloss: 19.05440902709961
# step: 400 batchloss: 16.354694366455078
# step: 500 batchloss: 13.813687324523926
# step: 600 batchloss: 17.109495162963867
# step: 700 batchloss: 16.131120681762695
# step: 800 batchloss: 21.439542770385742
# step: 900 batchloss: 17.233659744262695
# step: 1000 batchloss: 23.393585205078125
# step: 1100 batchloss: 18.030160903930664
# step: 1200 batchloss: 25.411617279052734
# step: 1300 batchloss: 19.837156295776367
# step: 1400 batchloss: 25.9503173828125
# step: 1500 batchloss: 21.155052185058594
# step: 1600 batchloss: 37.535648345947266
# step: 1700 batchloss: 26.956878662109375
# step: 1800 batchloss: 25.798002243041992
# step: 1900 batchloss: 33.60710525512695
# step: 2000 batchloss: 29.951047897338867
# step: 2100 batchloss: 29.519359588623047
# step: 2200 batchloss: 39.799076080322266
# step: 2300 batchloss: 36.67912673950195
# step: 2400 batchloss: 36.261749267578125
# step: 2500 batchloss: 36.88438415527344
# step: 2600 batchloss: 75.11357879638672
# step: 2700 batchloss: 63.23946762084961
# step: 2800 batchloss: 63.04840850830078
# step: 2900 batchloss: 61.99323272705078
# step: 3000 batchloss: 47.25456237792969
# step: 3100 batchloss: 55.242210388183594
# step: 3200 batchloss: 64.64411926269531
# step: 3300 batchloss: 94.0665283203125
# step: 3400 batchloss: 76.5822982788086
# step: 3500 batchloss: 80.19339752197266
# step: 3600 batchloss: 99.2147216796875
# step: 3700 batchloss: 88.86486053466797
# step: 3800 batchloss: 111.47735595703125
# step: 3900 batchloss: 132.83485412597656
# step: 4000 batchloss: 133.3329315185547
# step: 4100 batchloss: 219.39195251464844
# epoch 14 : loss 215433.7768215984
# bleu of epoch 14:  0.09387509913313506
# step: 0 batchloss: 0.16979463398456573
# step: 100 batchloss: 8.525394439697266
# step: 200 batchloss: 9.105690956115723
# step: 300 batchloss: 18.72862434387207
# step: 400 batchloss: 15.330923080444336
# step: 500 batchloss: 13.388391494750977
# step: 600 batchloss: 15.707390785217285
# step: 700 batchloss: 17.017932891845703
# step: 800 batchloss: 21.69064712524414
# step: 900 batchloss: 16.548622131347656
# step: 1000 batchloss: 21.697450637817383
# step: 1100 batchloss: 17.713302612304688
# step: 1200 batchloss: 25.0833740234375
# step: 1300 batchloss: 20.00035858154297
# step: 1400 batchloss: 25.723237991333008
# step: 1500 batchloss: 21.406421661376953
# step: 1600 batchloss: 37.106388092041016
# step: 1700 batchloss: 26.68570899963379
# step: 1800 batchloss: 24.87701416015625
# step: 1900 batchloss: 32.79477310180664
# step: 2000 batchloss: 29.30082130432129
# step: 2100 batchloss: 28.82412338256836
# step: 2200 batchloss: 37.85173797607422
# step: 2300 batchloss: 34.74167251586914
# step: 2400 batchloss: 35.40773391723633
# step: 2500 batchloss: 36.85588836669922
# step: 2600 batchloss: 70.84249114990234
# step: 2700 batchloss: 59.737754821777344
# step: 2800 batchloss: 59.423553466796875
# step: 2900 batchloss: 59.30915451049805
# step: 3000 batchloss: 45.45258712768555
# step: 3100 batchloss: 53.30331802368164
# step: 3200 batchloss: 62.58146286010742
# step: 3300 batchloss: 88.30733489990234
# step: 3400 batchloss: 73.16963195800781
# step: 3500 batchloss: 77.10066986083984
# step: 3600 batchloss: 94.76179504394531
# step: 3700 batchloss: 85.55443572998047
# step: 3800 batchloss: 107.25780487060547
# step: 3900 batchloss: 131.71475219726562
# step: 4000 batchloss: 129.91162109375
# step: 4100 batchloss: 213.0688934326172
# epoch 15 : loss 208045.9917512238
# step: 0 batchloss: 0.11879583448171616
# step: 100 batchloss: 8.733312606811523
# step: 200 batchloss: 9.07790470123291
# step: 300 batchloss: 18.574697494506836
# step: 400 batchloss: 15.643169403076172
# step: 500 batchloss: 13.287435531616211
# step: 600 batchloss: 15.282959938049316
# step: 700 batchloss: 16.292510986328125
# step: 800 batchloss: 20.5430850982666
# step: 900 batchloss: 15.85278606414795
# step: 1000 batchloss: 20.680160522460938
# step: 1100 batchloss: 17.822668075561523
# step: 1200 batchloss: 23.350404739379883
# step: 1300 batchloss: 18.454072952270508
# step: 1400 batchloss: 24.59461784362793
# step: 1500 batchloss: 19.870264053344727
# step: 1600 batchloss: 34.875083923339844
# step: 1700 batchloss: 25.755334854125977
# step: 1800 batchloss: 24.520061492919922
# step: 1900 batchloss: 32.63467025756836
# step: 2000 batchloss: 28.89554214477539
# step: 2100 batchloss: 28.050613403320312
# step: 2200 batchloss: 37.28301239013672
# step: 2300 batchloss: 33.39771270751953
# step: 2400 batchloss: 34.638336181640625
# step: 2500 batchloss: 34.46245574951172
# step: 2600 batchloss: 68.46825408935547
# step: 2700 batchloss: 58.769474029541016
# step: 2800 batchloss: 59.02941131591797
# step: 2900 batchloss: 57.639400482177734
# step: 3000 batchloss: 44.40219497680664
# step: 3100 batchloss: 51.70225143432617
# step: 3200 batchloss: 60.59468078613281
# step: 3300 batchloss: 88.10477447509766
# step: 3400 batchloss: 71.48596954345703
# step: 3500 batchloss: 76.55149841308594
# step: 3600 batchloss: 92.75299835205078
# step: 3700 batchloss: 84.4892807006836
# step: 3800 batchloss: 105.39146423339844
# step: 3900 batchloss: 130.33213806152344
# step: 4000 batchloss: 125.24092102050781
# step: 4100 batchloss: 209.86585998535156
# epoch 16 : loss 203890.57281187177
# bleu of epoch 16:  0.09270312168523198
# step: 0 batchloss: 0.19324998557567596
# step: 100 batchloss: 8.232739448547363
# step: 200 batchloss: 8.923551559448242
# step: 300 batchloss: 18.501914978027344
# step: 400 batchloss: 15.135796546936035
# step: 500 batchloss: 12.325419425964355
# step: 600 batchloss: 15.54306697845459
# step: 700 batchloss: 15.13495922088623
# step: 800 batchloss: 19.774822235107422
# step: 900 batchloss: 15.911624908447266
# step: 1000 batchloss: 21.149412155151367
# step: 1100 batchloss: 16.24704360961914
# step: 1200 batchloss: 23.226022720336914
# step: 1300 batchloss: 19.72731590270996
# step: 1400 batchloss: 23.473636627197266
# step: 1500 batchloss: 19.8438663482666
# step: 1600 batchloss: 34.08006286621094
# step: 1700 batchloss: 24.761474609375
# step: 1800 batchloss: 23.50971794128418
# step: 1900 batchloss: 30.051002502441406
# step: 2000 batchloss: 27.65243911743164
# step: 2100 batchloss: 26.70521354675293
# step: 2200 batchloss: 34.95139694213867
# step: 2300 batchloss: 33.971656799316406
# step: 2400 batchloss: 33.62843322753906
# step: 2500 batchloss: 34.01785659790039
# step: 2600 batchloss: 68.42253875732422
# step: 2700 batchloss: 57.093570709228516
# step: 2800 batchloss: 56.12913131713867
# step: 2900 batchloss: 57.11214828491211
# step: 3000 batchloss: 44.14879608154297
# step: 3100 batchloss: 49.88384246826172
# step: 3200 batchloss: 61.66842269897461
# step: 3300 batchloss: 85.90858459472656
# step: 3400 batchloss: 70.64981842041016
# step: 3500 batchloss: 75.48177337646484
# step: 3600 batchloss: 92.98577880859375
# step: 3700 batchloss: 83.53958129882812
# step: 3800 batchloss: 103.66921997070312
# step: 3900 batchloss: 129.2741241455078
# step: 4000 batchloss: 123.50244903564453
# step: 4100 batchloss: 209.00311279296875
# epoch 17 : loss 200540.28323201835
# step: 0 batchloss: 0.12589477002620697
# step: 100 batchloss: 7.919247627258301
# step: 200 batchloss: 8.7584810256958
# step: 300 batchloss: 17.71707534790039
# step: 400 batchloss: 14.328780174255371
# step: 500 batchloss: 11.793233871459961
# step: 600 batchloss: 14.790334701538086
# step: 700 batchloss: 14.501199722290039
# step: 800 batchloss: 20.080148696899414
# step: 900 batchloss: 15.21151351928711
# step: 1000 batchloss: 20.21540069580078
# step: 1100 batchloss: 16.784950256347656
# step: 1200 batchloss: 22.767236709594727
# step: 1300 batchloss: 18.258865356445312
# step: 1400 batchloss: 23.07087516784668
# step: 1500 batchloss: 19.055065155029297
# step: 1600 batchloss: 33.68503952026367
# step: 1700 batchloss: 23.194910049438477
# step: 1800 batchloss: 23.361862182617188
# step: 1900 batchloss: 30.0673828125
# step: 2000 batchloss: 26.92293357849121
# step: 2100 batchloss: 27.393043518066406
# step: 2200 batchloss: 34.2482795715332
# step: 2300 batchloss: 31.8529109954834
# step: 2400 batchloss: 32.91218948364258
# step: 2500 batchloss: 33.1023063659668
# step: 2600 batchloss: 65.22303771972656
# step: 2700 batchloss: 56.338523864746094
# step: 2800 batchloss: 56.70405960083008
# step: 2900 batchloss: 55.70594787597656
# step: 3000 batchloss: 43.725799560546875
# step: 3100 batchloss: 50.02627182006836
# step: 3200 batchloss: 60.17738723754883
# step: 3300 batchloss: 85.73371887207031
# step: 3400 batchloss: 69.859375
# step: 3500 batchloss: 75.4881362915039
# step: 3600 batchloss: 92.4331283569336
# step: 3700 batchloss: 81.95801544189453
# step: 3800 batchloss: 105.86676788330078
# step: 3900 batchloss: 128.46873474121094
# step: 4000 batchloss: 125.0809555053711
# step: 4100 batchloss: 204.292236328125
# epoch 18 : loss 197675.94930624962
# bleu of epoch 18:  0.09384027835749241
# step: 0 batchloss: 0.19071686267852783
# step: 100 batchloss: 7.967336177825928
# step: 200 batchloss: 8.734092712402344
# step: 300 batchloss: 17.123214721679688
# step: 400 batchloss: 14.294672966003418
# step: 500 batchloss: 12.178625106811523
# step: 600 batchloss: 14.589722633361816
# step: 700 batchloss: 15.208563804626465
# step: 800 batchloss: 19.866348266601562
# step: 900 batchloss: 14.058634757995605
# step: 1000 batchloss: 19.22823143005371
# step: 1100 batchloss: 15.911518096923828
# step: 1200 batchloss: 21.479473114013672
# step: 1300 batchloss: 18.128246307373047
# step: 1400 batchloss: 23.461910247802734
# step: 1500 batchloss: 18.510635375976562
# step: 1600 batchloss: 33.49541091918945
# step: 1700 batchloss: 23.227148056030273
# step: 1800 batchloss: 22.983722686767578
# step: 1900 batchloss: 28.908828735351562
# step: 2000 batchloss: 27.404754638671875
# step: 2100 batchloss: 27.625322341918945
# step: 2200 batchloss: 33.793025970458984
# step: 2300 batchloss: 31.9394474029541
# step: 2400 batchloss: 31.17266845703125
# step: 2500 batchloss: 33.23704147338867
# step: 2600 batchloss: 64.42588806152344
# step: 2700 batchloss: 54.93974304199219
# step: 2800 batchloss: 54.804046630859375
# step: 2900 batchloss: 53.92950439453125
# step: 3000 batchloss: 41.43732452392578
# step: 3100 batchloss: 50.99638366699219
# step: 3200 batchloss: 59.27788543701172
# step: 3300 batchloss: 85.9441146850586
# step: 3400 batchloss: 68.2745590209961
# step: 3500 batchloss: 73.84065246582031
# step: 3600 batchloss: 89.63622283935547
# step: 3700 batchloss: 81.91459655761719
# step: 3800 batchloss: 102.07767486572266
# step: 3900 batchloss: 127.11421966552734
# step: 4000 batchloss: 124.54283905029297
# step: 4100 batchloss: 205.99081420898438
# epoch 19 : loss 195174.74281533062
# Done at: 8584.699269294739

# %%
def test():
    total = 0
    correct = 0
    model = BiLSTMEncDec(vocablist_en,vocabidx_en,vocablist_vi,vocabidx_vi).to(DEVICE)
    model.load_state_dict(torch.load(MODELNAME))
    model.eval()
    ref = []
    pred =[]
    for enprep, en, vi in test_data:
        input =  torch.tensor([enprep], dtype=torch.int64).transpose(0,1).to(DEVICE)
        p = model.evaluate(input, vocablist_vi,vocabidx_vi)
        print('INPUT',en)
        print('REF',vi)
        print('MT',p)
        ref.append([vi])
        pred.append(p)
    bleu = torchtext.data.metrics.bleu_score(pred,ref)
    print('total:',len(test_data))
    print('bleu:',bleu)

# %% [markdown]
# Testing

# %%
test()
# Out:
# INPUT ['When', 'I', 'was', 'little', ',', 'I', 'thought', 'my', 'country', 'was', 'the', 'best', 'on', 'the', 'planet', ',', 'and', 'I', 'grew', 'up', 'singing', 'a', 'song', 'called', '&quot;', 'Nothing', 'To', 'Envy', '.', '&quot;']
# REF ['Khi', 'tôi', 'còn', 'nhỏ', ',', 'Tôi', 'nghĩ', 'rằng', 'BắcTriều', 'Tiên', 'là', 'đất', 'nước', 'tốt', 'nhất', 'trên', 'thế', 'giới', 'và', 'tôi', 'thường', 'hát', 'bài', '&quot;', 'Chúng', 'ta', 'chẳng', 'có', 'gì', 'phải', 'ghen', 'tị', '.', '&quot;']
# MT ['Khi', 'tôi', 'lớn', 'lên', ',', 'tôi', 'là', 'một', 'nhà', 'thiên', 'văn', 'thế', 'giới', 'tên', 'là', '&quot;', 'Tôi', 'là', 'một', 'ngôi', 'sao', 'tuyệt', 'vời', 'và', 'tôi', 'nghĩ', 'rằng', '&quot;', 'Không', 'có']
# INPUT ['And', 'I', 'was', 'very', 'proud', '.']
# REF ['Tôi', 'đã', 'rất', 'tự', 'hào', 'về', 'đất', 'nước', 'tôi', '.']
# MT ['Và', 'tôi', 'rất', 'tự', 'hào', '.']
# INPUT ['In', 'school', ',', 'we', 'spent', 'a', 'lot', 'of', 'time', 'studying', 'the', 'history', 'of', 'Kim', 'Il-Sung', ',', 'but', 'we', 'never', 'learned', 'much', 'about', 'the', 'outside', 'world', ',', 'except', 'that', 'America', ',', 'South', 'Korea', ',', 'Japan', 'are', 'the', 'enemies', '.']
# REF ['Ở', 'trường', ',', 'chúng', 'tôi', 'dành', 'rất', 'nhiều', 'thời', 'gian', 'để', 'học', 'về', 'cuộc', 'đời', 'của', 'chủ', 'tịch', 'Kim', 'II-', 'Sung', ',', 'nhưng', 'lại', 'không', 'học', 'nhiều', 'về', 'thế', 'giới', 'bên', 'ngoài', ',', 'ngoại', 'trừ', 'việc', 'Hoa', 'Kỳ', ',', 'Hàn', 'Quốc', 'và', 'Nhật', 'Bản', 'là', 'kẻ', 'thù', 'của', 'chúng', 'tôi', '.']
# MT ['Vào', 'năm', '<unk>', ',', 'chúng', 'ta', 'đã', 'học', 'rất', 'nhiều', 'về', 'lịch', 'sử', 'vũ', 'trụ', ',', 'lịch', 'sử', 'Mỹ', ',', 'nhưng', 'không', 'bao', 'giờ', 'là', 'chúng', 'ta', ',', 'trừ', 'phi']
# INPUT ['Although', 'I', 'often', 'wondered', 'about', 'the', 'outside', 'world', ',', 'I', 'thought', 'I', 'would', 'spend', 'my', 'entire', 'life', 'in', 'North', 'Korea', ',', 'until', 'everything', 'suddenly', 'changed', '.']
# REF ['Mặc', 'dù', 'tôi', 'đã', 'từng', 'tự', 'hỏi', 'không', 'biết', 'thế', 'giới', 'bên', 'ngoài', 'kia', 'như', 'thế', 'nào', ',', 'nhưng', 'tôi', 'vẫn', 'nghĩ', 'rằng', 'mình', 'sẽ', 'sống', 'cả', 'cuộc', 'đời', 'ở', 'BắcTriều', 'Tiên', ',', 'cho', 'tới', 'khi', 'tất', 'cả', 'mọi', 'thứ', 'đột', 'nhiên', 'thay', 'đổi', '.']
# MT ['Mặc', 'dù', 'tôi', 'đã', 'nghĩ', 'về', 'tất', 'cả', 'mọi', 'thứ', 'khắp', 'thế', 'giới', ',', 'nếu', 'tôi', 'nghĩ', 'về', 'bất', 'cứ', 'nơi', 'đâu', ',', 'tôi', 'sẽ', 'đi', 'khắp', 'nơi', 'trên', 'thế']
# INPUT ['When', 'I', 'was', 'seven', 'years', 'old', ',', 'I', 'saw', 'my', 'first', 'public', 'execution', ',', 'but', 'I', 'thought', 'my', 'life', 'in', 'North', 'Korea', 'was', 'normal', '.']
# REF ['Khi', 'tôi', 'lên', '7', ',', 'tôi', 'chứng', 'kiến', 'cảnh', 'người', 'ta', 'xử', 'bắn', 'công', 'khai', 'lần', 'đầu', 'tiên', 'trong', 'đời', ',', 'nhưng', 'tôi', 'vẫn', 'nghĩ', 'cuộc', 'sống', 'của', 'mình', 'ở', 'đây', 'là', 'hoàn', 'toàn', 'bình', 'thường', '.']
# MT ['Khi', 'tôi', '15', 'tuổi', ',', 'tôi', 'nhìn', 'thấy', 'công', 'việc', 'của', 'mình', 'là', 'tôi', 'nghĩ', 'rằng', 'mình', 'đang', 'sống', 'ở', 'Bắc', 'Triều', 'Tiên', 'của', 'Bắc', 'Mỹ', ',', 'nhưng', 'khi', 'mà']
# INPUT ['My', 'family', 'was', 'not', 'poor', ',', 'and', 'myself', ',', 'I', 'had', 'never', 'experienced', 'hunger', '.']
# REF ['Gia', 'đình', 'của', 'tôi', 'không', 'nghèo', ',', 'và', 'bản', 'thân', 'tôi', 'thì', 'chưa', 'từng', 'phải', 'chịu', 'đói', '.']
# MT ['Gia', 'đình', 'tôi', 'không', 'hề', 'có', 'kinh', 'nghiệm', ',', 'tôi', 'chưa', 'bao', 'giờ', 'bị', 'đói', 'kém', ',', 'không', 'bao', 'giờ', 'có', 'đủ', 'tiền', '.']
# INPUT ['But', 'one', 'day', ',', 'in', '1995', ',', 'my', 'mom', 'brought', 'home', 'a', 'letter', 'from', 'a', 'coworker', '&apos;s', 'sister', '.']
# REF ['Nhưng', 'vào', 'một', 'ngày', 'của', 'năm', '1995', ',', 'mẹ', 'tôi', 'mang', 'về', 'nhà', 'một', 'lá', 'thư', 'từ', 'một', 'người', 'chị', 'em', 'cùng', 'chỗ', 'làm', 'với', 'mẹ', '.']
# MT ['Nhưng', 'vào', 'ngày', 'nọ', ',', 'một', 'tháng', ',', 'mẹ', 'tôi', 'đã', 'mang', 'một', 'quyển', 'nhật', 'ký', 'từ', 'một', 'người', 'mẹ', '.']
# INPUT ['It', 'read', ',', '&quot;', 'When', 'you', 'read', 'this', ',', 'all', 'five', 'family', 'members', 'will', 'not', 'exist', 'in', 'this', 'world', ',', 'because', 'we', 'haven', '&apos;t', 'eaten', 'for', 'the', 'past', 'two', 'weeks', '.']
# REF ['Trong', 'đó', 'có', 'viết', ':', 'Khi', 'chị', 'đọc', 'được', 'những', 'dòng', 'này', 'thì', 'cả', 'gia', 'đình', '5', 'người', 'của', 'em', 'đã', 'không', 'còn', 'trên', 'cõi', 'đời', 'này', 'nữa', ',', 'bởi', 'vì', 'cả', 'nhà', 'em', 'đã', 'không', 'có', 'gì', 'để', 'ăn', 'trong', 'hai', 'tuần', '.']
# MT ['<unk>', 'Thomas', ',', 'trong', 'quyển', 'sách', 'này', ',', 'bạn', 'đọc', 'quyển', 'sách', 'này', 'trong', 'vòng', '18', 'tháng', ',', 'vì', 'nếu', 'không', 'có', 'đủ', 'các', 'tác', 'phẩm', 'mà', 'chúng', 'tôi', 'đã']
# INPUT ['We', 'are', 'lying', 'on', 'the', 'floor', 'together', ',', 'and', 'our', 'bodies', 'are', 'so', 'weak', 'we', 'are', 'ready', 'to', 'die', '.', '&quot;']
# REF ['Tất', 'cả', 'cùng', 'nằm', 'trên', 'sàn', ',', 'và', 'cơ', 'thể', 'chúng', 'tôi', 'yếu', 'đến', 'có', 'thể', 'cảm', 'thấy', 'như', 'cái', 'chết', 'đang', 'đến', 'rất', 'gần', '.']
# MT ['Chúng', 'ta', 'đang', 'ở', 'trong', 'lồng', 'ngực', ',', 'và', 'khuôn', 'mặt', 'chúng', 'ta', 'sẵn', 'sàng', 'bỏ', 'lỡ', 'cơ', 'hội', 'để', 'sinh', 'sống', '.', '&quot;']
# INPUT ['I', 'was', 'so', 'shocked', '.']
# REF ['Tôi', 'đã', 'bị', 'sốc', '.']
# MT ['Tôi', 'đã', 'sốc', 'sức', 'mạnh', '.']
# INPUT ['This', 'was', 'the', 'first', 'time', 'I', 'heard', 'that', 'people', 'in', 'my', 'country', 'were', 'suffering', '.']
# REF ['Vì', 'đó', 'là', 'lần', 'đầu', 'tiên', 'tôi', 'biết', 'rằng', 'đồng', 'bào', 'của', 'tôi', 'đang', 'phải', 'chịu', 'đựng', 'như', 'vậy', '.']
# MT ['Đây', 'là', 'lần', 'đầu', 'tiên', 'tôi', 'nghe', 'thấy', 'người', 'dân', 'ở', 'đất', 'nước', 'mình', 'bị', 'thất', 'vọng', '.']
# INPUT ['Soon', 'after', ',', 'when', 'I', 'was', 'walking', 'past', 'a', 'train', 'station', ',', 'I', 'saw', 'something', 'terrible', 'that', 'I', 'can', '&apos;t', 'erase', 'from', 'my', 'memory', '.']
# REF ['Không', 'lâu', 'sau', 'đó', ',', 'khi', 'tôi', 'đi', 'qua', 'một', 'nhà', 'ga', ',', 'tôi', 'nhìn', 'thấy', 'một', 'cảnh', 'tượng', 'kinh', 'hoàng', 'mà', 'tôi', 'không', 'bao', 'giờ', 'có', 'thể', 'quên']
# MT ['Ngay', 'sau', 'khi', 'tôi', 'đi', 'thăm', 'một', 'chuyến', 'xe', 'buýt', ',', 'tôi', 'thấy', 'mình', 'có', 'thể', 'mở', 'khoá', 'cửa', 'ra', 'sao', ',', 'tôi', 'không', 'thể', 'tự', 'nhận', 'ra', 'được', 'từ']
# INPUT ['A', 'lifeless', 'woman', 'was', 'lying', 'on', 'the', 'ground', ',', 'while', 'an', 'emaciated', 'child', 'in', 'her', 'arms', 'just', 'stared', 'helplessly', 'at', 'his', 'mother', '&apos;s', 'face', '.']
# REF ['Trên', 'nền', 'nhà', 'ga', 'là', 'xác', 'chết', 'của', 'một', 'người', 'đàn', 'bà', 'hai', 'tay', 'vẫn', 'đang', 'ôm', 'một', 'đứa', 'bé', 'hốc', 'hác', 'và', 'đứa', 'bé', 'chỉ', 'biết', 'nhìn', 'chằm', 'chằm', 'vào', 'khuôn', 'mặt', 'của', 'mẹ', 'nó', '.']
# MT ['Một', 'phụ', 'nữ', 'đeo', 'thai', 'ở', 'một', 'bên', 'khuôn', 'mặt', ',', 'khi', 'mẹ', 'mới', 'nằm', 'dưới', 'chân', 'bà', 'mẹ', 'mình', ',', 'khi', 'cô', 'bé', 'bị', 'ảnh', 'hưởng', 'bởi', 'khuôn', 'mặt']
# INPUT ['But', 'nobody', 'helped', 'them', ',', 'because', 'they', 'were', 'so', 'focused', 'on', 'taking', 'care', 'of', 'themselves', 'and', 'their', 'families', '.']
# REF ['Nhưng', 'không', 'có', 'ai', 'giúp', 'họ', ',', 'bởi', 'vì', 'tất', 'cả', 'đều', 'đang', 'phải', 'lo', 'cho', 'chính', 'mình', 'và', 'cả', 'gia', 'đình', '.']
# MT ['Nhưng', 'không', 'ai', 'dạy', 'họ', ',', 'vì', 'họ', 'không', 'tự', 'cứu', 'mình', 'vì', 'họ', 'không', 'thể', 'tự', 'chăm', 'sóc', 'bản', 'thân', 'mình', 'và', 'gia', 'đình', 'của', 'họ', '.']
# INPUT ['A', 'huge', 'famine', 'hit', 'North', 'Korea', 'in', 'the', 'mid-1990s', '.']
# REF ['Vào', 'giữa', 'những', 'năm', '90', ',', 'Bắc', 'Triều', 'Tiên', 'trải', 'qua', 'một', 'nạn', 'đói', 'trầm', 'trọng', '.']
# MT ['Một', 'đợt', 'bùng', 'nổ', 'Bắc', 'Triều', 'Tiên', 'ở', 'Bắc', 'Triều', 'Tiên', 'ở', 'Bắc', 'Mỹ', '.']
# INPUT ['Ultimately', ',', 'more', 'than', 'a', 'million', 'North', 'Koreans', 'died', 'during', 'the', 'famine', ',', 'and', 'many', 'only', 'survived', 'by', 'eating', 'grass', ',', 'bugs', 'and', 'tree', 'bark', '.']
# REF ['Nó', 'khiến', 'hơn', 'một', 'triệu', 'người', 'Triều', 'Tiên', 'chết', 'trong', 'nạn', 'đói', ',', 'và', 'nhiều', 'người', 'chỉ', 'sống', 'sót', 'phải', 'ăn', 'cỏ', ',', 'sâu', 'bọ', 'và', 'vỏ', 'cây', '.']
# MT ['Hơn', 'nữa', ',', 'hơn', 'nữa', ',', 'hơn', 'cả', 'ngàn', 'người', 'thiệt', 'mạng', 'sống', ',', 'chỉ', 'còn', '21', 'triệu', 'người', ',', 'và', 'gần', 'như', 'giết', 'chết', 'người', 'dân', ',', 'sống', 'sót']
# INPUT ['Power', 'outages', 'also', 'became', 'more', 'and', 'more', 'frequent', ',', 'so', 'everything', 'around', 'me', 'was', 'completely', 'dark', 'at', 'night', 'except', 'for', 'the', 'sea', 'of', 'lights', 'in', 'China', ',', 'just', 'across', 'the', 'river', 'from', 'my', 'home', '.']
# REF ['Việc', 'cúp', 'điện', 'ngày', 'càng', 'xảy', 'ra', 'thường', 'xuyên', ',', 'vì', 'thế', 'mọi', 'thứ', 'xung', 'quanh', 'tôi', 'đều', 'chìm', 'vào', 'bóng', 'tối', 'khi', 'đêm', 'đến', 'ngoại', 'trừ', 'ánh', 'sáng', 'đèn', 'từ', 'phía', 'Trung', 'Quốc', 'chỉ', 'cách', 'nhà', 'tôi', 'một', 'con', 'sông', '.']
# MT ['<unk>', 'cũng', 'trở', 'nên', 'xa', 'lạ', 'với', 'tất', 'cả', 'mọi', 'thứ', 'khác', ',', 'và', 'tôi', 'hoàn', 'toàn', 'bị', 'chìm', 'trong', 'suốt', 'mấy', 'tiếng', 'đồng', 'hồ', 'để', 'lau', 'nắng', 'từ', 'Trung']
# INPUT ['I', 'always', 'wondered', 'why', 'they', 'had', 'lights', 'but', 'we', 'didn', '&apos;t', '.']
# REF ['Tôi', 'lúc', 'nào', 'cũng', 'tự', 'hỏi', 'là', 'tại', 'sao', 'họ', 'lại', 'có', 'điện', 'còn', 'chúng', 'tôi', 'thì', 'không', '.']
# MT ['Tôi', 'luôn', 'tự', 'hỏi', 'vì', 'sao', 'họ', 'có', 'thể', 'làm', 'vậy', 'nhưng', 'chúng', 'ta', 'không', 'có', 'được', 'nó', '.']
# INPUT ['This', 'is', 'a', 'satellite', 'picture', 'showing', 'North', 'Korea', 'at', 'night', 'compared', 'to', 'neighbors', '.']
# REF ['Đây', 'là', 'một', 'bức', 'ảnh', 'từ', 'vệ', 'tinh', 'chụp', 'Bắc', 'Triều', 'Tiên', 'vào', 'ban', 'đêm', 'trong', 'tương', 'quan', 'với', 'các', 'nước', 'xung', 'quanh', '.']
# MT ['Đây', 'là', 'một', 'bức', 'ảnh', 'chụp', 'ảnh', 'chụp', 'ảnh', 'so', 'với', 'vũ', 'trụ', 'so', 'với', 'các', 'bóng', 'đen', '.']
# INPUT ['This', 'is', 'the', 'Amrok', 'River', ',', 'which', 'serves', 'as', 'a', 'part', 'of', 'the', 'border', 'between', 'North', 'Korea', 'and', 'China', '.']
# REF ['Đây', 'là', 'sông', 'Áp', 'Lục', 'nó', 'là', 'biên', 'giới', 'tự', 'nhiên', 'giữa', 'Bắc', 'Triều', 'Tiên', 'và', 'Trung', 'Quốc', '.']
# MT ['Đây', 'là', 'Bắc', 'Băng', 'Dương', ',', 'đường', 'ray', 'được', 'xây', 'dựng', 'ở', 'phía', 'Bắc', 'Kenya', 'và', 'Trung', 'Quốc', 'là', 'một', 'phần', 'giữa', 'Hàn', 'Quốc', 'và', 'Trung', 'Quốc', '.']
# INPUT ['As', 'you', 'can', 'see', ',', 'the', 'river', 'can', 'be', 'very', 'narrow', 'at', 'certain', 'points', ',', 'allowing', 'North', 'Koreans', 'to', 'secretly', 'cross', '.']
# REF ['Có', 'thể', 'thấy', 'là', 'lòng', 'sông', 'có', 'đoạn', 'rất', 'hẹp', 'vì', 'thế', 'một', 'số', 'người', 'Bắc', 'Triều', 'Tiên', 'bí', 'mật', 'vượt', 'sang', 'Trung', 'Quốc', '.']
# MT ['Như', 'các', 'bạn', 'có', 'thể', 'thấy', ',', 'có', 'nhiều', 'đường', 'kẻ', 'đang', 'vận', 'chuyển', 'những', 'phương', 'tiện', 'giao', 'thông', 'để', 'có', 'thể', 'che', 'giấu', 'những', 'khoáng', 'chất', 'đang', 'diễn', 'ra']
# INPUT ['But', 'many', 'die', '.']
# REF ['Nhưng', 'rất', 'nhiều', 'người', 'đã', 'chết', '.']
# MT ['Nhưng', 'nhiều', 'người', 'chết', '.']
# INPUT ['Sometimes', ',', 'I', 'saw', 'dead', 'bodies', 'floating', 'down', 'the', 'river', '.']
# REF ['Và', 'tôi', 'đã', 'nhìn', 'thấy', 'xác', 'họ', 'nổi', 'trên', 'sông', '.']
# MT ['Thỉnh', 'thoảng', ',', 'tôi', 'đã', 'thoát', 'khỏi', 'bờ', 'sông', 'xuống', 'sông', 'sông', '.']
# INPUT ['I', 'can', '&apos;t', 'reveal', 'many', 'details', '&#91;', 'about', '&#93;', 'how', 'I', 'left', 'North', 'Korea', ',', 'but', 'I', 'only', 'can', 'say', 'that', 'during', 'the', 'ugly', 'years', 'of', 'the', 'famine', 'I', 'was', 'sent', 'to', 'China', 'to', 'live', 'with', 'distant', 'relatives', '.']
# REF ['Tôi', 'không', 'thể', 'nói', 'cụ', 'thể', 'về', 'việc', 'mình', 'đã', 'trốn', 'khỏi', 'Bắc', 'Triều', 'Tiên', 'như', 'thế', 'nào', 'chỉ', 'có', 'thể', 'nói', 'rằng', 'trong', 'những', 'năm', 'tháng', 'khốn', 'khó', 'vì', 'nạn', 'đói', 'ấy', 'tôi', 'được', 'gửi', 'sang', 'Trung', 'Quốc', 'để', 'sống', 'với', 'một', 'người', 'họ', 'hàng', 'xa', '.']
# MT ['Tôi', 'không', 'thể', 'nói', 'nhiều', 'về', 'cách', 'mà', 'tôi', 'có', 'thể', 'đi', 'xa', 'hơn', 'nữa', ',', 'nhưng', 'tôi', 'biết', 'rằng', 'tôi', 'đã', 'nói', 'với', 'các', 'nhà', 'nông', 'dân', 'Trung', 'Quốc']
# INPUT ['But', 'I', 'only', 'thought', 'that', 'I', 'would', 'be', 'separated', 'from', 'my', 'family', 'for', 'a', 'short', 'time', '.']
# REF ['Lúc', 'đó', ',', 'tôi', 'chỉ', 'nghĩ', 'rằng', 'mình', 'sẽ', 'phải', 'xa', 'gia', 'đình', 'một', 'thời', 'gian', 'ngắn', '.']
# MT ['Nhưng', 'tôi', 'nghĩ', 'rằng', 'tôi', 'sẽ', 'dành', 'thời', 'gian', 'dài', 'để', 'tách', 'biệt', 'với', 'gia', 'đình', 'mình', '.']
# INPUT ['I', 'could', 'have', 'never', 'imagined', 'that', 'it', 'would', 'take', '14', 'years', 'to', 'live', 'together', '.']
# REF ['chứ', 'không', 'bao', 'giờ', 'tôi', 'có', 'thể', 'tưởng', 'tượng', 'rằng', 'tôi', 'sẽ', 'phải', 'xa', 'họ', 'những', '14', 'năm', 'ròng', '.']
# MT ['Tôi', 'không', 'bao', 'giờ', 'đoán', 'rằng', 'sẽ', 'không', 'bao', 'giờ', 'sống', 'được', '14', 'năm', 'để', 'sống', '.']
# INPUT ['In', 'China', ',', 'it', 'was', 'hard', 'living', 'as', 'a', 'young', 'girl', 'without', 'my', 'family', '.']
# REF ['Ở', 'Trung', 'Quốc', ',', 'cuộc', 'sống', 'của', 'một', 'cô', 'bé', 'bị', 'cách', 'ly', 'khỏi', 'gia', 'đình', 'như', 'tôi', 'rất', 'khó', 'khăn', '.']
# MT ['Ở', 'South', 'nước', 'đó', ',', 'nó', 'là', 'một', 'người', 'mẹ', 'tuyệt', 'vời', ',', 'không', 'cần', 'gia', 'đình', 'tôi', '.']
# INPUT ['I', 'had', 'no', 'idea', 'what', 'life', 'was', 'going', 'to', 'be', 'like', 'as', 'a', 'North', 'Korean', 'refugee', ',', 'but', 'I', 'soon', 'learned', 'it', '&apos;s', 'not', 'only', 'extremely', 'difficult', ',', 'it', '&apos;s', 'also', 'very', 'dangerous', ',', 'since', 'North', 'Korean', 'refugees', 'are', 'considered', 'in', 'China', 'as', 'illegal', 'migrants', '.']
# REF ['Tôi', 'đã', 'không', 'tưởng', 'được', 'những', 'gì', 'xảy', 'đến', 'với', 'cuộc', 'sống', 'của', 'một', 'người', 'tị', 'nạn', 'từ', 'Bắc', 'Triều', 'Tiên', 'thì', 'sẽ', 'như', 'thế', 'nào', ',', 'nhưng', 'tôi', 'sớm', 'nhận', 'ra', 'rằng', 'nó', 'không', 'những', 'rất', 'khó', 'khăn', ',', 'mà', 'còn', 'vô', 'cùng', 'nguy', 'hiểm', ',', 'vì', 'những', 'người', 'tị', 'nạn', 'từ', 'Bắc', 'Triều', 'Tiên', 'vào', 'Trung', 'Quốc', 'đều', 'bị', 'coi', 'là', 'dân', 'nhập', 'cư', 'trái', 'phép', '.']
# MT ['Tôi', 'không', 'biết', 'cuộc', 'sống', 'của', 'một', 'cuộc', 'khủng', 'hoảng', 'dân', 'tộc', 'như', 'thế', 'nào', 'là', 'ở', 'Bắc', 'Triều', 'Tiên', ',', 'nhưng', 'tôi', 'vẫn', 'còn', 'sống', 'ở', 'Bắc', 'Mỹ', ',']
# INPUT ['So', 'I', 'was', 'living', 'in', 'constant', 'fear', 'that', 'my', 'identity', 'could', 'be', 'revealed', ',', 'and', 'I', 'would', 'be', 'repatriated', 'to', 'a', 'horrible', 'fate', 'back', 'in', 'North', 'Korea', '.']
# REF ['Tôi', 'luôn', 'sống', 'trong', 'một', 'nỗi', 'sợ', 'thường', 'trực', 'rằng', 'danh', 'tính', 'của', 'tôi', 'sẽ', 'bị', 'phát', 'hiện', ',', 'và', 'tôi', 'sẽ', 'bị', 'trả', 'về', 'với', 'cuộc', 'sống', 'cũ', 'ở', 'Bắc', 'Triều', 'Tiên', '.']
# MT ['Tôi', 'đang', 'sống', 'trong', 'nỗi', 'sợ', 'hãi', 'niềm', 'tự', 'hào', 'về', 'khả', 'năng', 'lãnh', 'đạo', ',', 'và', 'tôi', 'bị', 'ám', 'ảnh', 'bởi', 'một', 'sự', 'biến', 'đổi', 'kinh', 'tế', 'rằng', 'tôi']
# INPUT ['One', 'day', ',', 'my', 'worst', 'nightmare', 'came', 'true', ',', 'when', 'I', 'was', 'caught', 'by', 'the', 'Chinese', 'police', 'and', 'brought', 'to', 'the', 'police', 'station', 'for', 'interrogation', '.']
# REF ['Một', 'ngày', ',', 'cơn', 'ác', 'mộng', 'đó', 'đã', 'thành', 'sự', 'thật', ',', 'tôi', 'đã', 'bị', 'cảnh', 'sát', 'Trung', 'Quốc', 'bắt', 'và', 'đưa', 'đến', 'đồn', 'cảnh', 'sát', 'để', 'chất', 'vấn', '.']
# MT ['Một', 'ngày', 'tồi', 'tệ', ',', 'tôi', 'đã', 'rơi', 'vào', 'cảnh', 'sát', 'của', 'mình', 'để', 'cảnh', 'sát', 'cảnh', 'sát', 'và', 'cảnh', 'sát', 'cảnh', 'sát', 'cảnh', 'sát', 'và', 'cảnh', 'sát', 'bế', 'tắc']
# INPUT ['Someone', 'had', 'accused', 'me', 'of', 'being', 'North', 'Korean', ',', 'so', 'they', 'tested', 'my', 'Chinese', 'language', 'abilities', 'and', 'asked', 'me', 'tons', 'of', 'questions', '.']
# REF ['Có', 'ai', 'đó', 'đã', 'báo', 'với', 'họ', 'rằng', 'tôi', 'là', 'người', 'Bắc', 'Triều', 'Tiên', ',', 'vì', 'thế', 'họ', 'đã', 'kiểm', 'tra', 'khả', 'năng', 'tiếng', 'Trung', 'của', 'tôi', 'và', 'hỏi', 'tôi', 'rất', 'nhiều', 'câu', 'hỏi', '.']
# MT ['Một', 'người', 'nào', 'đó', 'đã', 'từng', 'chứng', 'kiến', 'tiếng', 'Tây', 'Ban', 'Nha', ',', 'vì', 'tiếng', 'Tây', 'Ban', 'Nha', 'của', 'tôi', 'đã', 'nghe', 'tiếng', 'Tây', 'Ban', 'Nha', 'và', 'hỏi', 'tôi', 'rất']
# INPUT ['I', 'was', 'so', 'scared', ',', 'I', 'thought', 'my', 'heart', 'was', 'going', 'to', 'explode', '.']
# REF ['Tôi', 'đã', 'vô', 'cùng', 'sợ', 'hãi', ',', 'và', 'có', 'cảm', 'giác', 'như', 'tim', 'mình', 'sắp', 'nổ', 'tung', '.']
# MT ['Tôi', 'rất', 'sợ', 'hãi', ',', 'tôi', 'sẽ', 'nghĩ', 'rằng', 'tim', 'đập', 'sẽ', 'ngừng', 'lại', '.']
# INPUT ['If', 'anything', 'seemed', 'unnatural', ',', 'I', 'could', 'be', 'imprisoned', 'and', 'repatriated', '.']
# REF ['Vì', 'nếu', 'như', 'họ', 'thấy', 'có', 'điều', 'gì', 'không', 'tự', 'nhiên', ',', 'tôi', 'sẽ', 'bị', 'tống', 'vào', 'tù', 'và', 'rồi', 'bị', 'trả', 'về', 'nước', '.']
# MT ['Nếu', 'có', 'thể', 'điều', 'chỉnh', ',', 'tôi', 'có', 'thể', 'làm', 'được', ',', 'cũng', 'như', 'là', '<unk>', 'và', '<unk>', '.']
# INPUT ['I', 'thought', 'my', 'life', 'was', 'over', ',', 'but', 'I', 'managed', 'to', 'control', 'all', 'the', 'emotions', 'inside', 'me', 'and', 'answer', 'the', 'questions', '.']
# REF ['Tôi', 'nghĩ', 'cuộc', 'đời', 'mình', 'đến', 'đây', 'là', 'chấm', 'dứt', ',', 'nhưng', 'tôi', 'vẫn', 'cố', 'gắng', 'điều', 'khiển', 'những', 'cảm', 'xúc', 'của', 'mình', 'và', 'trả', 'lời', 'những', 'câu', 'hỏi', 'của', 'họ', '.']
# MT ['Tôi', 'nghĩ', 'cuộc', 'đời', 'mình', ',', 'nhưng', 'tôi', 'đã', 'vượt', 'qua', 'tất', 'cả', 'sự', 'kiểm', 'soát', 'của', 'mình', 'và', 'cảm', 'giác', 'được', 'trả', 'lời', 'là', 'đặt', 'câu', 'hỏi', 'cho', 'mọi']
# INPUT ['After', 'they', 'finished', 'questioning', 'me', ',', 'one', 'official', 'said', 'to', 'another', ',', '&quot;', 'This', 'was', 'a', 'false', 'report', '.']
# REF ['Sau', 'khi', 'hỏi', 'xong', ',', 'một', 'trong', 'hai', 'cảnh', 'sát', 'nói', 'với', 'người', 'kia', ',', 'Đây', 'là', 'một', 'vụ', 'chỉ', 'điểm', 'sai', '.']
# MT ['Sau', 'khi', 'họ', 'giải', 'thích', ',', 'một', 'câu', 'hỏi', 'khác', 'là', ',', '&quot;', 'Một', 'nghệ', 'sĩ', 'đã', 'xuất', 'bản', ',', 'đó', 'là', 'một', 'sai', 'lầm', '.']
# INPUT ['She', '&apos;s', 'not', 'North', 'Korean', '.', '&quot;']
# REF ['Nó', 'không', 'phải', 'là', 'người', 'Bắc', 'Triều', 'Tiên', '.', '&quot;']
# MT ['Cô', 'ấy', 'không', 'được', 'huấn', 'luyện', 'tại', 'Bắc', 'Triều', 'tiên', '.', '&quot;']
# INPUT ['And', 'they', 'let', 'me', 'go', '.', 'It', 'was', 'a', 'miracle', '.']
# REF ['Và', 'họ', 'thả', 'tôi', 'ra', '.', 'Đó', 'quả', 'là', 'một', 'phép', 'màu', '.']
# MT ['Và', 'để', 'tôi', 'đưa', 'ra', 'một', 'ý', 'tưởng', '.', 'Nó', 'là', 'một', 'sự', 'thật', '.']
# INPUT ['Some', 'North', 'Koreans', 'in', 'China', 'seek', 'asylum', 'in', 'foreign', 'embassies', ',', 'but', 'many', 'can', 'be', 'caught', 'by', 'the', 'Chinese', 'police', 'and', 'repatriated', '.']
# REF ['Một', 'số', 'người', 'Bắc', 'Triều', 'Tiên', 'ở', 'Trung', 'Quốc', 'đã', 'đến', 'những', 'đại', 'sứ', 'quán', 'của', 'nước', 'ngoài', 'để', 'xin', 'tị', 'nạn', ',', 'nhưng', 'rất', 'nhiều', 'trong', 'số', 'đó', 'đã', 'bị', 'bắt', 'bởi', 'cảnh', 'sát', 'Trung', 'Quốc', 'và', 'bị', 'trả', 'về', 'nước', '.']
# MT ['Một', 'vài', 'người', 'đi', 'khắp', 'Trung', 'Quốc', 'Bắc', 'Triều', 'Tiên', 'ở', 'Bắc', 'Triều', 'Tiên', ',', 'có', 'lẽ', 'đã', 'phát', 'tán', 'rất', 'nhiều', 'miền', 'bắc', 'Canada', 'nhưng', 'cũng', 'có', 'thể', 'bị']
# INPUT ['These', 'girls', 'were', 'so', 'lucky', '.']
# REF ['những', 'cô', 'gái', 'này', 'đã', 'rất', 'may', 'mắn', '.']
# MT ['Những', 'cô', 'gái', 'này', 'rất', 'may', 'mắn', '.']
# INPUT ['Even', 'though', 'they', 'were', 'caught', ',', 'they', 'were', 'eventually', 'released', 'after', 'heavy', 'international', 'pressure', '.']
# REF ['vì', 'mặc', 'dù', 'đã', 'bị', 'bắt', ',', 'nhưng', 'cuối', 'cùng', 'học', 'cũng', 'được', 'thả', 'ra', 'nhờ', 'vào', 'sức', 'ép', 'từ', 'cộng', 'đồng', 'quốc', 'tế', '.']
# MT ['Dù', 'họ', 'đã', 'cắm', 'trại', 'sau', 'Công', 'viên', 'quốc', 'tế', ',', 'sau', 'khi', 'được', 'đưa', 'lên', 'đài', 'phát', 'thanh', 'quốc', 'tế', '.']
# INPUT ['These', 'North', 'Koreans', 'were', 'not', 'so', 'lucky', '.']
# REF ['Nhưng', 'những', 'người', 'Bắc', 'Triều', 'Tiên', 'này', 'thì', 'không', 'được', 'may', 'mắn', 'như', 'vậy', '.']
# MT ['Những', 'người', 'này', 'đã', 'không', 'phải', 'đối', 'mặt', 'với', 'những', 'ai', 'thực', 'sự', 'may', 'mắn', '.']
# INPUT ['Every', 'year', ',', 'countless', 'North', 'Koreans', 'are', 'caught', 'in', 'China', 'and', 'repatriated', 'to', 'North', 'Korea', ',', 'where', 'they', 'can', 'be', 'tortured', ',', 'imprisoned', 'or', 'publicly', 'executed', '.']
# REF ['Hàng', 'năm', ',', 'có', 'vô', 'số', 'người', 'Bắc', 'Triều', 'Tiên', 'bị', 'bắt', 'ở', 'Trung', 'Quốc', 'và', 'bị', 'trả', 'về', 'nước', ',', 'nơi', 'mà', 'họ', 'bị', 'tra', 'tấn', ',', 'bị', 'giam', 'cầm', 'hoặc', 'bị', 'xử', 'tử', 'công', 'khai', '.']
# MT ['Hàng', 'năm', ',', 'bất', 'cứ', 'khi', 'nào', 'Kim', 'đến', 'Bắc', 'Triều', 'Tiên', 'và', 'Trung', 'Quốc', 'được', 'đào', 'tạo', 'và', 'họ', 'có', 'thể', 'đến', 'Bắc', 'Hàn', 'hay', 'Thổ', 'Nhĩ', 'Kỳ', ',']
# INPUT ['Even', 'though', 'I', 'was', 'really', 'fortunate', 'to', 'get', 'out', ',', 'many', 'other', 'North', 'Koreans', 'have', 'not', 'been', 'so', 'lucky', '.']
# REF ['Trong', 'khi', 'tôi', 'rất', 'may', 'mắn', 'vì', 'đã', 'được', 'thả', 'ra', 'thì', 'rất', 'nhiều', 'đồng', 'bào', 'của', 'tôi', 'lại', 'không', 'được', 'như', 'vậy', '.']
# MT ['Mặc', 'dù', 'tôi', 'rất', 'may', 'mắn', 'vì', 'nhiều', 'người', 'trong', 'số', 'các', 'chuyến', 'thăm', 'quan', 'vẫn', 'còn', 'chưa', 'đủ', ',', 'rất', 'nhiều', 'người', 'đã', 'đến', '.']
# INPUT ['It', '&apos;s', 'tragic', 'that', 'North', 'Koreans', 'have', 'to', 'hide', 'their', 'identities', 'and', 'struggle', 'so', 'hard', 'just', 'to', 'survive', '.']
# REF ['Việc', 'người', 'Bắc', 'Triều', 'Tiên', 'phải', 'che', 'dấu', 'danh', 'tính', 'của', 'mình', 'và', 'đấu', 'tranh', 'để', 'tồn', 'tại', 'quả', 'là', 'một', 'bi', 'kịch', '.']
# MT ['Rõ', 'ràng', 'là', 'con', 'người', 'đã', 'bị', 'lạc', 'hướng', 'để', 'vượt', 'qua', 'những', 'khó', 'khăn', 'để', 'vượt', 'qua', 'và', 'để', 'tồn', 'tại', '.']
# INPUT ['Even', 'after', 'learning', 'a', 'new', 'language', 'and', 'getting', 'a', 'job', ',', 'their', 'whole', 'world', 'can', 'be', 'turned', 'upside', 'down', 'in', 'an', 'instant', '.']
# REF ['Kể', 'cả', 'khi', 'đã', 'học', 'tiếng', 'Trung', 'và', 'tìm', 'được', 'một', 'công', 'việc', ',', 'thì', 'cuộc', 'sống', 'của', 'họ', 'cũng', 'có', 'thể', 'bị', 'đảo', 'lộn', 'hoàn', 'toàn', 'chỉ', 'trong', 'một', 'khoảng', 'khắc', '.']
# MT ['Ngay', 'cả', 'khi', 'một', 'kỹ', 'thuật', 'và', 'một', 'thế', 'giới', 'mới', 'có', 'thể', 'được', 'làm', ',', 'và', 'nhận', 'ra', 'rằng', 'cả', 'thế', 'giới', 'sẽ', 'được', 'chuyển', 'hoá', 'qua', 'một', 'giai']
# INPUT ['That', '&apos;s', 'why', ',', 'after', '10', 'years', 'of', 'hiding', 'my', 'identity', ',', 'I', 'decided', 'to', 'risk', 'going', 'to', 'South', 'Korea', ',', 'and', 'I', 'started', 'a', 'new', 'life', 'yet', 'again', '.']
# REF ['Đó', 'là', 'lý', 'do', 'tại', 'sao', 'sau', '10', 'năm', 'che', 'dấu', 'danh', 'tính', 'thật', 'tôi', 'quyết', 'định', 'liều', 'mình', 'đi', 'đến', 'Hàn', 'Quốc', ',', 'để', 'bắt', 'đầu', 'một', 'cuộc', 'sống', 'mới', 'một', 'lần', 'nữa', '.']
# MT ['Đó', 'là', 'lí', 'do', 'tại', 'sao', ',', 'sau', 'một', 'nửa', 'năm', ',', 'tôi', 'quyết', 'định', 'sẽ', 'cải', 'thiện', 'cuộc', 'sống', 'của', 'mình', ',', 'và', 'tôi', 'quyết', 'định', 'rời', 'khỏi', 'quê']
# INPUT ['Settling', 'down', 'in', 'South', 'Korea', 'was', 'a', 'lot', 'more', 'challenging', 'than', 'I', 'had', 'expected', '.']
# REF ['Việc', 'ổn', 'định', 'cuộc', 'sống', 'ở', 'đây', 'khó', 'khăn', 'hơn', 'nhiều', 'so', 'với', 'tôi', 'tưởng', 'tượng', '.']
# MT ['<unk>', 'ở', 'miền', 'Nam', 'Kenya', 'hơn', 'nhiều', 'là', 'tôi', 'càng', 'ngạc', 'nhiên', 'hơn', 'nhiều', '.']
# INPUT ['English', 'was', 'so', 'important', 'in', 'South', 'Korea', ',', 'so', 'I', 'had', 'to', 'start', 'learning', 'my', 'third', 'language', '.']
# REF ['Vì', 'ở', 'Hàn', 'Quốc', ',', 'tiếng', 'Anh', 'có', 'vị', 'trí', 'vô', 'cùng', 'quan', 'trọng', ',', 'nên', 'tôi', 'đã', 'bắt', 'đầu', 'học', 'tiếng', 'Anh', ',', 'ngôn', 'ngữ', 'thứ', 'ba', 'của', 'tôi', '.']
# MT ['Tiếng', 'Trung', 'Quốc', 'rất', 'quan', 'trọng', 'ở', 'Ấn', 'Độ', ',', 'tôi', 'bắt', 'đầu', 'học', 'đại', 'học', 'thứ', 'ba', 'của', 'mình', '.']
# INPUT ['Also', ',', 'I', 'realized', 'there', 'was', 'a', 'wide', 'gap', 'between', 'North', 'and', 'South', '.']
# REF ['Tôi', 'cũng', 'nhận', 'ra', 'một', 'khoảng', 'cách', 'rất', 'lớn', 'giữa', 'người', 'Nam', 'và', 'Bắc', 'Triều', 'Tiên', '.']
# MT ['Tôi', 'nhận', 'ra', 'rằng', 'có', 'một', 'khoảng', 'cách', 'lớn', 'giữa', 'Nam', 'Cực', 'và', 'khoảng', 'cách', 'giữa', 'Nam', 'Cực', '.']
# INPUT ['We', 'are', 'all', 'Korean', ',', 'but', 'inside', ',', 'we', 'have', 'become', 'very', 'different', 'due', 'to', '67', 'years', 'of', 'division', '.']
# REF ['Chúng', 'tôi', 'đều', 'là', 'người', 'Triều', 'Tiên', ',', 'nhưng', 'đã', 'trở', 'nên', 'rất', 'khác', 'nhau', 'do', 'hậu', 'quả', 'của', '67', 'năm', 'bị', 'chia', 'cắt', '.']
# MT ['Chúng', 'ta', 'đều', 'là', 'những', 'người', 'Do', 'Thái', ',', 'nhưng', 'chúng', 'ta', 'đã', 'ở', 'ngoài', 'gần', 'đây', ',', 'nhưng', 'ở', '<unk>', ',', 'chúng', 'ta', 'đã', 'có', 'rất', 'nhiều', 'sự', 'khác']
# INPUT ['I', 'even', 'went', 'through', 'an', 'identity', 'crisis', '.']
# REF ['Tôi', 'đã', 'trải', 'qua', 'một', 'cuộc', 'khủng', 'hoảng', 'về', 'nguồn', 'gốc', 'của', 'mình', '.']
# MT ['Tôi', 'thậm', 'chí', 'còn', 'đi', 'qua', 'một', 'khủng', 'hoảng', 'toàn', 'cầu', 'về', 'khủng', 'hoảng', '.']
# INPUT ['Am', 'I', 'South', 'Korean', 'or', 'North', 'Korean', '?']
# REF ['Tôi', 'là', 'người', 'Nam', 'Triều', 'Tiên', 'hay', 'Bắc', 'Triều', 'Tiên', '?']
# MT ['Tôi', 'đã', 'từng', 'là', 'phóng', 'viên', 'Tây', 'Ban', 'Nha', 'hay', 'Bắc', 'Triều', 'Tiên', '?']
# INPUT ['Where', 'am', 'I', 'from', '?', 'Who', 'am', 'I', '?']
# REF ['Tôi', 'đến', 'từ', 'đâu', '?', 'và', 'Tôi', 'là', 'ai', '?']
# MT ['Tôi', 'ở', 'đâu', '?', 'Tôi', 'là', 'ai', '?']
# INPUT ['Suddenly', ',', 'there', 'was', 'no', 'country', 'I', 'could', 'proudly', 'call', 'my', 'own', '.']
# REF ['Bỗng', 'nhiên', ',', 'tôi', 'chẳng', 'có', 'một', 'đất', 'nước', 'nào', 'để', 'có', 'thể', 'tự', 'hào', 'gọi', 'là', 'Tổ', 'quốc', '.']
# MT ['Đột', 'nhiên', ',', 'không', 'có', 'đất', 'nước', 'tôi', 'có', 'thể', 'gọi', 'là', 'chính', 'quyền', 'của', 'mình', '.']
# INPUT ['Even', 'though', 'adjusting', 'to', 'life', 'in', 'South', 'Korea', 'was', 'not', 'easy', ',', 'I', 'made', 'a', 'plan', '.']
# REF ['Mặc', 'dù', 'để', 'thích', 'ứng', 'với', 'cuộc', 'sống', 'ở', 'Hàn', 'Quốc', 'thì', 'không', 'dễ', 'chút', 'nào', 'Nhưng', 'tôi', 'đã', 'lập', 'một', 'kế', 'hoạch', '.']
# MT ['Mặc', 'dù', 'vậy', ',', 'dù', 'có', 'sự', 'sống', 'ở', 'South', 'Phi', ',', 'tôi', 'không', 'hề', 'dễ', 'dàng', 'làm', 'gì', ',', 'tôi', 'đã', 'tạo', 'ra', 'một', 'kế', 'hoạch', 'kì', 'diệu', '.']
# INPUT ['I', 'started', 'studying', 'for', 'the', 'university', 'entrance', 'exam', '.']
# REF ['và', 'bắt', 'đầu', 'học', 'để', 'chuẩn', 'bị', 'cho', 'kì', 'thi', 'đại', 'học', '.']
# MT ['Tôi', 'bắt', 'đầu', 'nghiên', 'cứu', 'về', 'trường', 'học', 'vào', 'năm', '1999', '.']
# INPUT ['Just', 'as', 'I', 'was', 'starting', 'to', 'get', 'used', 'to', 'my', 'new', 'life', ',', 'I', 'received', 'a', 'shocking', 'phone', 'call', '.']
# REF ['Tuy', 'vậy', ',', 'ngay', 'khi', 'tôi', 'vừa', 'mới', 'làm', 'quen', 'với', 'cuộc', 'sống', 'ở', 'đây', ',', 'thì', 'tôi', 'được', 'báo', 'một', 'tin', 'khủng', 'khiếp', '.']
# MT ['Cũng', 'như', 'lần', 'tôi', 'bắt', 'đầu', 'nhận', 'thấy', 'cuộc', 'đời', 'mình', 'đã', 'có', 'một', 'cuộc', 'đời', 'mình', ',', 'tôi', 'nhận', 'được', 'một', 'cuộc', 'gọi', 'về', 'nhà', 'máy', 'điện', 'tử', '.']
# INPUT ['The', 'North', 'Korean', 'authorities', 'intercepted', 'some', 'money', 'that', 'I', 'sent', 'to', 'my', 'family', ',', 'and', ',', 'as', 'a', 'punishment', ',', 'my', 'family', 'was', 'going', 'to', 'be', 'forcibly', 'removed', 'to', 'a', 'desolate', 'location', 'in', 'the', 'countryside', '.']
# REF ['Chính', 'quyền', 'Bắc', 'Triều', 'Tiên', 'đã', 'phát', 'hiện', 'ra', 'số', 'tiền', 'mà', 'tôi', 'gửi', 'về', 'cho', 'gia', 'đình', ',', 'và', ',', 'để', 'trừng', 'phạt', ',', 'họ', 'sẽ', 'bắt', 'gia', 'đình', 'tôi', 'phải', 'chuyển', 'về', 'một', 'vùng', 'bị', 'cách', 'ly', 'ở', 'nông', 'thôn', '.']
# MT ['Nhà', 'nước', 'địa', 'phương', 'thường', 'đổ', 'nước', 'cho', 'tôi', ',', 'và', 'tôi', 'cũng', 'sẽ', 'rời', 'bỏ', 'gia', 'đình', ',', 'và', 'một', 'gia', 'đình', 'gắn', 'bó', 'chặt', 'chẽ', 'với', 'tôi', ',']
# INPUT ['They', 'had', 'to', 'get', 'out', 'quickly', ',', 'so', 'I', 'started', 'planning', 'how', 'to', 'help', 'them', 'escape', '.']
# REF ['Để', 'họ', 'có', 'thể', 'nhanh', 'chóng', 'thoát', 'ra', 'khỏi', 'đó', ',', 'tôi', 'bắt', 'đầu', 'lập', 'kế', 'hoạch', 'giúp', 'gia', 'đình', 'mình', 'trốn', 'thoát', '.']
# MT ['Họ', 'đã', 'tránh', 'được', 'việc', 'làm', ',', 'tôi', 'bắt', 'đầu', 'làm', 'việc', 'để', 'giúp', 'đỡ', 'họ', '.']
# INPUT ['North', 'Koreans', 'have', 'to', 'travel', 'incredible', 'distances', 'on', 'the', 'path', 'to', 'freedom', '.']
# REF ['Người', 'Bắc', 'Triều', 'Tiên', 'đã', 'phải', 'vượt', 'qua', 'những', 'khoảng', 'cách', 'dường', 'như', 'không', 'tưởng', 'để', 'đến', 'với', 'tự', 'do', '.']
# MT ['Những', 'người', 'dân', 'Bắc', 'Triều', 'tiên', 'cũng', 'di', 'chuyển', 'tới', 'tận', 'Bắc', 'Cực', 'để', 'đi', 'du', 'lịch', '.']
# INPUT ['It', '&apos;s', 'almost', 'impossible', 'to', 'cross', 'the', 'border', 'between', 'North', 'Korea', 'and', 'South', 'Korea', ',', 'so', ',', 'ironically', ',', 'I', 'took', 'a', 'flight', 'back', 'to', 'China', 'and', 'I', 'headed', 'toward', 'the', 'North', 'Korean', 'border', '.']
# REF ['Bời', 'vì', 'việc', 'vượt', 'biên', 'từ', 'Bắc', 'sang', 'Nam', 'Triều', 'Tiên', 'gần', 'như', 'là', 'không', 'thể', ',', 'vì', 'thế', ',', 'tôi', 'phải', 'bay', 'sang', 'Trung', 'Quốc', 'rồi', 'lại', 'đi', 'ngược', 'về', 'phía', 'biên', 'giới', 'Bắc', 'Triều', 'Tiên', '.']
# MT ['Gần', 'như', 'không', 'bao', 'giờ', 'được', 'so', 'sánh', 'giữa', 'Hàn', 'Quốc', 'và', 'Hàn', 'Quốc', 'và', 'Hoa', 'Kỳ', ',', 'tôi', 'đã', 'chuyển', 'giao', 'Hàn', 'Quốc', 'Bắc', 'Mỹ', 'và', 'tôi', 'đã', 'dấn']
# INPUT ['Since', 'my', 'family', 'couldn', '&apos;t', 'speak', 'Chinese', ',', 'I', 'had', 'to', 'guide', 'them', ',', 'somehow', ',', 'through', 'more', 'than', '2,000', 'miles', 'in', 'China', 'and', 'then', 'into', 'Southeast', 'Asia', '.']
# REF ['Bởi', 'vì', 'gia', 'đình', 'tôi', 'không', 'biết', 'tiếng', 'Trung', ',', 'nên', 'tôi', 'phải', 'đi', 'cùng', 'mọi', 'người', 'qua', '2000', 'dặm', 'ở', 'Trung', 'Quốc', 'rồi', 'vào', 'đến', 'Đông', 'Nam', 'Á']
# MT ['Kể', 'từ', 'khi', 'tôi', 'không', 'nói', 'tiếng', 'Trung', 'Quốc', ',', 'tôi', 'phải', 'đi', 'sâu', 'vào', 'Trung', 'Quốc', ',', 'sau', 'đó', ',', 'đi', 'qua', 'New', 'Zealand', ',', 'ở', 'Trung', 'Đông', 'và']
# INPUT ['The', 'journey', 'by', 'bus', 'took', 'one', 'week', ',', 'and', 'we', 'were', 'almost', 'caught', 'several', 'times', '.']
# REF ['Cuộc', 'hành', 'trình', 'bằng', 'xe', 'buýt', 'kéo', 'dài', 'khoảng', '1', 'tuần', ',', 'và', 'đã', 'vài', 'lần', 'chúng', 'tôi', 'suýt', 'bị', 'bắt', '.']
# MT ['Chuyến', 'hành', 'trình', 'qua', 'một', 'tuần', 'sau', 'đó', ',', 'chúng', 'tôi', 'đã', 'bị', 'trễ', 'vài', 'tuần', 'liền', '.']
# INPUT ['One', 'time', ',', 'our', 'bus', 'was', 'stopped', 'and', 'boarded', 'by', 'a', 'Chinese', 'police', 'officer', '.']
# REF ['Một', 'lần', ',', 'xe', 'của', 'chúng', 'tôi', 'bị', 'chặn', 'lại', 'và', 'bị', 'khám', 'xét', 'bởi', 'một', 'cảnh', 'sát', 'Trung', 'quốc', '.']
# MT ['Một', 'lần', ',', 'quân', 'lính', 'bị', 'bắn', 'và', 'bắn', 'và', 'bắn', 'ra', 'đường', 'phố', 'của', 'chúng', 'tôi', 'bị', 'đánh', 'cắp', 'bởi', 'một', 'viên', 'cảnh', 'sát', '.']
# INPUT ['He', 'took', 'everyone', '&apos;s', 'I.D.', 'cards', ',', 'and', 'he', 'started', 'asking', 'them', 'questions', '.']
# REF ['Anh', 'ta', 'thu', 'chứng', 'minh', 'thư', 'của', 'tất', 'cả', 'mọi', 'người', ',', 'và', 'bắt', 'đầu', 'tra', 'hỏi', '.']
# MT ['Ông', 'ta', 'đã', 'viết', 'thư', 'cho', 'các', 'đồng', 'nghiệp', ',', 'và', 'ông', 'bắt', 'đầu', 'trả', 'lời', 'câu', 'hỏi', 'của', 'họ', '.']
# INPUT ['Since', 'my', 'family', 'couldn', '&apos;t', 'understand', 'Chinese', ',', 'I', 'thought', 'my', 'family', 'was', 'going', 'to', 'be', 'arrested', '.']
# REF ['Bởi', 'vì', 'gia', 'đình', 'tôi', 'không', 'hiểu', 'tiếng', 'Trung', ',', 'nên', 'tôi', 'đã', 'nghĩ', 'rằng', 'họ', 'sẽ', 'bị', 'bắt', '.']
# MT ['Kể', 'từ', 'khi', 'gia', 'đình', 'tôi', 'không', 'thể', 'gia', 'nhập', 'gia', 'đình', ',', 'tôi', 'nghĩ', 'gia', 'đình', 'mình', 'sẽ', 'bắt', 'đầu', 'gia', 'đình', '.']
# INPUT ['As', 'the', 'Chinese', 'officer', 'approached', 'my', 'family', ',', 'I', 'impulsively', 'stood', 'up', ',', 'and', 'I', 'told', 'him', 'that', 'these', 'are', 'deaf', 'and', 'dumb', 'people', 'that', 'I', 'was', 'chaperoning', '.']
# REF ['Khi', 'người', 'cảnh', 'sát', 'Trung', 'Quốc', 'đến', 'gần', 'họ', ',', 'tôi', 'đã', 'ngay', 'lập', 'tức', 'đứng', 'dậy', 'và', 'nói', 'với', 'anh', 'ta', 'rằng', 'đây', 'là', 'những', 'người', 'câm', 'điếc', 'mà', 'tôi', 'đang', 'phải', 'đi', 'cùng', '.']
# MT ['Khi', 'các', 'đồng', 'nghiệp', 'đứng', 'ở', 'quê', 'nhà', 'tôi', ',', 'tôi', 'đứng', 'ở', 'đây', 'và', 'tôi', 'nói', 'với', 'tôi', 'rằng', ',', 'ông', 'là', 'người', 'đứng', 'đầu', 'và', 'ông', 'ấy', 'đã']
# INPUT ['He', 'looked', 'at', 'me', 'suspiciously', ',', 'but', 'luckily', 'he', 'believed', 'me', '.']
# REF ['Anh', 'ta', 'nhìn', 'tôi', 'đầy', 'nghi', 'ngờ', ',', 'nhưng', 'thật', 'may', 'mắn', 'là', 'anh', 'ta', 'tin', 'lời', 'tôi', '.']
# MT ['Ông', 'ta', 'nhìn', 'tôi', ',', 'nhưng', 'ông', 'tin', 'rằng', 'ông', 'ấy', 'tin', 'tưởng', 'rất', 'nhiều', 'điều', 'đấy', '.']
# INPUT ['We', 'made', 'it', 'all', 'the', 'way', 'to', 'the', 'border', 'of', 'Laos', ',', 'but', 'I', 'had', 'to', 'spend', 'almost', 'all', 'my', 'money', 'to', 'bribe', 'the', 'border', 'guards', 'in', 'Laos', '.']
# REF ['Và', 'chúng', 'tôi', 'tiếp', 'tục', 'đi', 'cho', 'tới', 'biên', 'giới', 'Lào', ',', 'nhung', 'tôi', 'đã', 'phải', 'sử', 'dụng', 'gần', 'như', 'toàn', 'bộ', 'số', 'tiền', 'mà', 'mình', 'có', 'để', 'hối', 'lộ', 'cho', 'những', 'người', 'canh', 'gác', 'biên', 'giới', 'Lào', '.']
# MT ['Chúng', 'tôi', 'đã', 'phải', 'vứt', 'hết', 'tất', 'cả', 'các', 'trạm', 'xăng', 'trên', 'mạng', ',', 'nhưng', 'tôi', 'phải', 'đưa', 'tất', 'cả', 'các', 'khoản', 'nợ', 'để', 'bỏ', 'phiếu', 'để', 'giết', 'các', 'biên']
# INPUT ['But', 'even', 'after', 'we', 'got', 'past', 'the', 'border', ',', 'my', 'family', 'was', 'arrested', 'and', 'jailed', 'for', 'illegal', 'border', 'crossing', '.']
# REF ['Tuy', 'nhiên', ',', 'sau', 'khi', 'chúng', 'tôi', 'qua', 'được', 'biên', 'giới', ',', 'gia', 'đình', 'tôi', 'lại', 'bị', 'bắt', 'vào', 'tù', 'vì', 'tội', 'vượt', 'biên', 'trái', 'phép', '.']
# MT ['Nhưng', 'thậm', 'chí', 'khi', 'chúng', 'tôi', 'bị', 'đưa', 'qua', 'biên', 'giới', ',', '<unk>', 'bị', 'tấn', 'công', 'và', 'bị', 'phá', 'huỷ', 'bởi', '<unk>', '<unk>', 'đã', 'bị', 'phá', 'huỷ', 'biên', 'giới', '.']
# INPUT ['After', 'I', 'paid', 'the', 'fine', 'and', 'bribe', ',', 'my', 'family', 'was', 'released', 'in', 'one', 'month', ',', 'but', 'soon', 'after', ',', 'my', 'family', 'was', 'arrested', 'and', 'jailed', 'again', 'in', 'the', 'capital', 'of', 'Laos', '.']
# REF ['Sau', 'khi', 'tôi', 'nộp', 'tiền', 'phạt', 'và', 'đưa', 'hối', 'lộ', ',', 'gia', 'đình', 'tôi', 'được', 'thả', 'ra', 'trong', 'một', 'tháng', ',', 'rồi', 'lại', 'bị', 'bắt', 'lần', 'nữa', 'ở', 'thủ', 'đô', 'của', 'Lào']
# MT ['Sau', 'khi', 'tôi', 'bị', 'đánh', 'mất', ',', 'gia', 'đình', 'tôi', 'và', 'gia', 'đình', 'tôi', 'bị', 'giam', 'giữ', ',', 'nhưng', 'sau', 'một', 'thời', 'gian', 'dài', ',', 'gia', 'đình', 'tôi', 'đã', 'bị']
# INPUT ['This', 'was', 'one', 'of', 'the', 'lowest', 'points', 'in', 'my', 'life', '.']
# REF ['Đó', 'là', 'thời', 'điểm', 'tuyệt', 'vọng', 'nhất', 'trong', 'cuộc', 'đời', 'tôi', '.']
# MT ['Đây', 'là', 'một', 'trong', 'những', 'điểm', 'lớn', 'nhất', 'của', 'cuộc', 'đời', 'tôi', '.']
# INPUT ['I', 'did', 'everything', 'to', 'get', 'my', 'family', 'to', 'freedom', ',', 'and', 'we', 'came', 'so', 'close', ',', 'but', 'my', 'family', 'was', 'thrown', 'in', 'jail', 'just', 'a', 'short', 'distance', 'from', 'the', 'South', 'Korean', 'embassy', '.']
# REF ['Tôi', 'đã', 'làm', 'đủ', 'mọi', 'cách', 'để', 'đưa', 'gia', 'đình', 'mình', 'đến', 'với', 'tự', 'do', ',', 'và', 'chũng', 'tôi', 'gần', 'như', 'đã', 'thành', 'công', 'nhưng', 'họ', 'lại', 'bị', 'bắt', 'trong', 'khi', 'chúng', 'tôi', 'chỉ', 'còn', 'cách', 'đại', 'sứ', 'quán', 'Hàn', 'Quốc', 'một', 'khoảng', 'cách', 'rất', 'ngắn', 'nữa', 'thôi', '.']
# MT ['Tôi', 'làm', 'việc', 'cho', 'gia', 'đình', 'mình', ',', 'nhưng', 'tôi', 'đã', 'thoát', 'khỏi', 'gia', 'đình', 'mình', ',', 'và', 'gia', 'đình', 'tôi', 'đã', 'thoát', 'khỏi', 'danh', 'sách', 'của', 'mình', 'để', 'thoát']
# INPUT ['I', 'went', 'back', 'and', 'forth', 'between', 'the', 'immigration', 'office', 'and', 'the', 'police', 'station', ',', 'desperately', 'trying', 'to', 'get', 'my', 'family', 'out', ',', 'but', 'I', 'didn', '&apos;t', 'have', 'enough', 'money', 'to', 'pay', 'a', 'bribe', 'or', 'fine', 'anymore', '.']
# REF ['Tôi', 'đi', 'đi', 'về', 'về', 'giữa', 'phòng', 'xuất', 'nhập', 'cảnh', 'và', 'đồn', 'cảnh', 'sát', ',', 'tuyệt', 'vọng', 'tìm', 'cách', 'để', 'đưa', 'gia', 'đình', 'mình', 'thoát', 'khỏi', 'đó', ',', 'nhưng', 'tôi', 'không', 'còn', 'đủ', 'tiền', 'để', 'hối', 'lộ', 'hay', 'trả', 'tiền', 'phạt', 'nữa', '.']
# MT ['Tôi', 'đi', 'ngược', 'lại', 'giữa', 'khách', 'sạn', 'và', 'đi', 'loanh', 'quanh', ',', 'nhưng', 'tôi', 'có', 'xu', 'hướng', 'trả', 'tiền', 'cho', 'khách', 'hàng', 'để', 'trả', 'tiền', 'cho', 'khách', 'hàng', ',', 'nhưng']
# INPUT ['I', 'lost', 'all', 'hope', '.']
# REF ['Tôi', 'hoàn', 'toàn', 'tuyệt', 'vọng', '.']
# MT ['Tôi', 'đã', 'thua', 'tất', 'cả', 'hy', 'vọng', '.']
# INPUT ['At', 'that', 'moment', ',', 'I', 'heard', 'one', 'man', '&apos;s', 'voice', 'ask', 'me', ',', '&quot;', 'What', '&apos;s', 'wrong', '?', '&quot;']
# REF ['Đúng', 'vào', 'lúc', 'đó', ',', 'có', 'một', 'người', 'đàn', 'ông', 'đã', 'hỏi', 'tôi', ',', '&quot;', 'Có', 'chuyện', 'gì', 'vậy', '?', '&quot;']
# MT ['Vào', 'lúc', 'đó', ',', 'tôi', 'hỏi', 'người', 'ta', ',', '&quot;', 'Ai', 'đó', 'đã', 'nói', 'gì', '?', '&quot;']
# INPUT ['I', 'was', 'so', 'surprised', 'that', 'a', 'total', 'stranger', 'cared', 'enough', 'to', 'ask', '.']
# REF ['Tôi', 'vô', 'cùng', 'ngạc', 'nhiên', 'khi', 'một', 'người', 'hoàn', 'toàn', 'xa', 'lạ', 'lại', 'quan', 'tâm', 'tới', 'mức', 'hỏi', 'tôi', 'như', 'vậy', '.']
# MT ['Tôi', 'ngạc', 'nhiên', 'khi', 'bất', 'cứ', 'ai', 'có', 'thể', 'xem', 'xét', 'đủ', 'số', 'lượng', 'người', 'nói', 'với', 'tôi', '.']
# INPUT ['In', 'my', 'broken', 'English', ',', 'and', 'with', 'a', 'dictionary', ',', 'I', 'explained', 'the', 'situation', ',', 'and', 'without', 'hesitating', ',', 'the', 'man', 'went', 'to', 'the', 'ATM', 'and', 'he', 'paid', 'the', 'rest', 'of', 'the', 'money', 'for', 'my', 'family', 'and', 'two', 'other', 'North', 'Koreans', 'to', 'get', 'out', 'of', 'jail', '.']
# REF ['Bằng', 'vốn', 'tiếng', 'Anh', 'ít', 'ỏi', 'của', 'mình', 'và', 'một', 'quyển', 'từ', 'điển', ',', 'tôi', 'đã', 'kể', 'cho', 'cho', 'ông', 'ta', 'nghe', 'hoàn', 'cảnh', 'của', 'gia', 'đình', 'tôi', '.', 'Không', 'một', 'chút', 'do', 'dự', ',', 'người', 'đàn', 'ông', 'đó', 'đã', 'đi', 'tới', 'máy', 'ATM.', 'trả', 'tất', 'cả', 'số', 'tiền', 'còn', 'thiếu', 'cho', 'cả', 'gia', 'đình', 'tôi', 'và', 'hai', 'người', 'Bắc', 'Triều', 'Tiên', 'khác', 'để', 'họ', 'được', 'ra', 'tù']
# MT ['Trong', 'văn', 'phòng', 'ngoại', 'giao', ',', 'và', 'bữa', 'ăn', 'của', 'tôi', ',', 'tôi', 'đã', 'thuê', 'một', 'cuộc', 'hành', 'trình', ',', 'và', 'không', 'phải', 'là', 'người', 'Việt', 'Nam', ',', 'ông', 'ấy']
# INPUT ['I', 'thanked', 'him', 'with', 'all', 'my', 'heart', ',', 'and', 'I', 'asked', 'him', ',', '&quot;', 'Why', 'are', 'you', 'helping', 'me', '?', '&quot;']
# REF ['Tôi', 'đã', 'cám', 'ơn', 'ông', 'ta', 'bằng', 'cả', 'trái', 'tim', 'mình', ',', 'và', 'tôi', 'cũng', 'hỏi', ',', '&quot;', 'Tại', 'sao', 'ông', 'lại', 'giúp', 'đỡ', 'tôi', '?', '&quot;']
# MT ['Tôi', 'tự', 'hỏi', 'ông', 'với', 'tất', 'cả', 'lòng', 'trắc', 'ẩn', ',', '&quot;', 'Tại', 'sao', 'ông', 'yêu', 'thương', 'tôi', ',', 'tôi', 'đã', 'giúp', 'ông', 'ấy', 'không', '?', '&quot;']
# INPUT ['&quot;', 'I', '&apos;m', 'not', 'helping', 'you', ',', '&quot;', 'he', 'said', '.']
# REF ['&quot;', 'Tôi', 'không', 'giúp', 'đỡ', 'cô', ',', '&quot;', 'Ông', 'ta', 'trả', 'lời', '.']
# MT ['&quot;', 'Tôi', 'không', 'giúp', 'ông', 'ấy', ',', '&quot;', 'ông', 'ấy', 'nói', 'với', 'ông', ':', '&quot;', '&apos;', '&apos;']
# INPUT ['&quot;', 'I', '&apos;m', 'helping', 'the', 'North', 'Korean', 'people', '.', '&quot;']
# REF ['&quot;', '&apos;', 'Tôi', 'đang', 'giúp', 'người', 'Bắc', 'Triều', 'Tiên', '.', '&quot;']
# MT ['&quot;', 'Tôi', 'làm', 'việc', 'cho', 'Bắc', 'Hàn', 'Quốc', '.', '&quot;']
# INPUT ['I', 'realized', 'that', 'this', 'was', 'a', 'symbolic', 'moment', 'in', 'my', 'life', '.']
# REF ['Tôi', 'nhận', 'ra', 'rằng', 'đó', 'là', 'một', 'khoảng', 'khắc', 'có', 'ý', 'nghĩa', 'vô', 'cùng', 'to', 'lớn', 'trong', 'cuộc', 'đời', 'tôi', '.']
# MT ['Tôi', 'nhận', 'ra', 'rằng', 'đây', 'là', 'khoảnh', 'khắc', 'của', 'một', 'khoảnh', 'khắc', 'riêng', 'lẽ', '.']
# INPUT ['The', 'kind', 'stranger', 'symbolized', 'new', 'hope', 'for', 'me', 'and', 'the', 'North', 'Korean', 'people', 'when', 'we', 'needed', 'it', 'most', ',', 'and', 'he', 'showed', 'me', 'the', 'kindness', 'of', 'strangers', 'and', 'the', 'support', 'of', 'the', 'international', 'community', 'are', 'truly', 'the', 'rays', 'of', 'hope', 'we', 'North', 'Korean', 'people', 'need', '.']
# REF ['Lòng', 'tốt', 'từ', 'người', 'đàn', 'ông', 'xa', 'lạ', 'trở', 'thành', 'biểu', 'tượng', 'hy', 'vọng', 'mới', 'cho', 'tôi', 'và', 'cả', 'những', 'người', 'dân', 'Bắc', 'Triều', 'Tiên', 'khi', 'mà', 'chúng', 'tôi', 'đang', 'rất', 'cần', 'nó', ',', 'và', 'ông', 'ta', 'đã', 'cho', 'tôi', 'thấy', 'lòng', 'tốt', 'từ', 'những', 'người', 'xa', 'lạ', 'và', 'sự', 'hỗ', 'trợ', 'của', 'cộng', 'đồng', 'quốc', 'tế', 'chính', 'là', 'những', 'tia', 'hy', 'vọng', 'mà', 'người', 'Bắc', 'Triều', 'Tiên', 'chúng', 'tôi', 'đang', 'tìm', 'kiếm', '.']
# MT ['Sự', 'xấu', 'hổ', 'chỉ', 'gây', 'hại', 'cho', 'tôi', 'khi', 'người', 'dân', 'Pakistan', 'và', 'những', 'người', 'phản', 'đối', 'thực', 'tế', 'rằng', 'chúng', 'ta', 'cần', 'sự', 'giúp', 'đỡ', 'của', 'chính', 'phủ', 'Hoa']
# INPUT ['Eventually', ',', 'after', 'our', 'long', 'journey', ',', 'my', 'family', 'and', 'I', 'were', 'reunited', 'in', 'South', 'Korea', ',', 'but', 'getting', 'to', 'freedom', 'is', 'only', 'half', 'the', 'battle', '.']
# REF ['Cuối', 'cùng', ',', 'sau', 'một', 'cuộc', 'hành', 'trình', 'dài', 'tôi', 'và', 'gia', 'đình', 'đã', 'được', 'đoàn', 'tụ', 'ở', 'Hàn', 'Quốc', ',', 'nhưng', 'đến', 'được', 'với', 'tự', 'do', 'mới', 'chỉ', 'là', 'một', 'nửa', 'của', 'cuộc', 'đấu', 'tranh', '.']
# MT ['Cuối', 'cùng', ',', 'tôi', 'nhập', 'cư', 'vượt', 'qua', 'tuổi', 'tác', 'của', 'tôi', 'và', 'Mexico', ',', 'nhưng', 'tôi', 'đã', 'bị', 'đưa', 'đến', 'một', 'nửa', 'trong', 'số', 'đó', ',', 'được', 'trưng', 'bày']
# INPUT ['Many', 'North', 'Koreans', 'are', 'separated', 'from', 'their', 'families', ',', 'and', 'when', 'they', 'arrive', 'in', 'a', 'new', 'country', ',', 'they', 'start', 'with', 'little', 'or', 'no', 'money', '.']
# REF ['Rất', 'nhiều', 'người', 'Bắc', 'Triều', 'Tiên', 'đang', 'bị', 'chia', 'cắt', 'với', 'gia', 'đình', 'của', 'họ', ',', 'và', 'khi', 'họ', 'đến', 'được', 'một', 'đất', 'nước', 'khác', ',', 'họ', 'phải', 'bắt', 'đầu', 'từ', 'đầu', 'với', 'rất', 'ít', 'hoặc', 'gần', 'như', 'không', 'có', 'tiền', 'bạc', '.']
# MT ['Rất', 'nhiều', 'làng', 'ở', 'xã', 'hội', 'gia', 'nhập', 'cư', 'dân', 'quê', 'hương', ',', 'khi', 'họ', 'bắt', 'đầu', 'gia', 'nhập', 'OECD', ',', 'họ', 'bắt', 'đầu', 'gia', 'nhập', 'gia', 'đình', 'hoặc', 'một']
# INPUT ['So', 'we', 'can', 'benefit', 'from', 'the', 'international', 'community', 'for', 'education', ',', 'English', 'language', 'training', ',', 'job', 'training', ',', 'and', 'more', '.']
# REF ['Vì', 'thế', 'chúng', 'tôi', 'có', 'thể', 'nhận', 'sự', 'trợ', 'giúp', 'từ', 'cộng', 'đồng', 'quốc', 'tế', 'cho', 'giáo', 'dục', ',', 'đào', 'tạo', 'tiếng', 'Anh', ',', 'dạy', 'nghề', ',', 'và', 'nhiều', 'lĩnh', 'vực', 'khác', '.']
# MT ['Vì', 'vậy', 'chúng', 'ta', 'có', 'thể', 'tạo', 'ra', 'lợi', 'nhuận', 'từ', 'những', 'cộng', 'đồng', 'truyền', 'thống', ',', 'giáo', 'dục', ',', 'đào', 'tạo', ',', 'nhiều', 'người', 'hơn', ',', 'nhiều', 'việc', 'làm']
# INPUT ['We', 'can', 'also', 'act', 'as', 'a', 'bridge', 'between', 'the', 'people', 'inside', 'North', 'Korea', 'and', 'the', 'outside', 'world', ',', 'because', 'many', 'of', 'us', 'stay', 'in', 'contact', 'with', 'family', 'members', 'still', 'inside', ',', 'and', 'we', 'send', 'information', 'and', 'money', 'that', 'is', 'helping', 'to', 'change', 'North', 'Korea', 'from', 'inside', '.']
# REF ['Chúng', 'tôi', 'cũng', 'có', 'thể', 'đóng', 'vai', 'trò', 'như', 'cầu', 'nối', 'giữa', 'những', 'người', 'đang', 'ở', 'trong', 'Bắc', 'Triều', 'Tiên', 'với', 'thế', 'giới', 'bên', 'ngoài', ',', 'bởi', 'vì', 'có', 'rất', 'nhiều', 'người', 'trong', 'chúng', 'tôi', 'đang', 'giữ', 'liên', 'lạc', 'với', 'những', 'thành', 'viên', 'gia', 'đình', 'khác', 'ở', 'trong', 'nước', ',', 'và', 'chúng', 'tôi', 'chia', 'sẻ', 'với', 'họ', 'thông', 'tin', 'và', 'tiền', 'bạc', 'để', 'có', 'thể', 'thay', 'đổi', 'Bắc', 'Triều', 'Tiên', 'từ', 'phía', 'trong', '.']
# MT ['Chúng', 'ta', 'cũng', 'có', 'thể', 'thay', 'đổi', 'hành', 'vi', 'của', 'mình', 'là', 'ở', 'Bắc', 'Uganda', 'và', 'Bắc', 'Triều', 'Tiên', ',', 'và', 'chúng', 'tôi', 'chuyển', 'giao', 'thông', 'xung', 'quanh', 'mình', 'và']
# INPUT ['I', '&apos;ve', 'been', 'so', 'lucky', ',', 'received', 'so', 'much', 'help', 'and', 'inspiration', 'in', 'my', 'life', ',', 'so', 'I', 'want', 'to', 'help', 'give', 'aspiring', 'North', 'Koreans', 'a', 'chance', 'to', 'prosper', 'with', 'international', 'support', '.']
# REF ['Tôi', 'đã', 'vô', 'cùng', 'may', 'mắn', 'khi', 'nhận', 'được', 'rất', 'nhiều', 'sự', 'giúp', 'đỡ', 'và', 'được', 'truyền', 'cảm', 'hứng', 'trong', 'suốt', 'cuộc', 'đời', 'mình', ',', 'vì', 'vậy', 'tôi', 'muốn', 'mình', 'cũng', 'có', 'thể', 'chung', 'sức', 'để', 'mang', 'đến', 'cho', 'đất', 'nước', 'tôi', 'một', 'cơ', 'hội', 'để', 'phát', 'triển', 'cùng', 'với', 'sự', 'hỗ', 'trợ', 'của', 'quốc', 'tế', '.']
# MT ['Tôi', 'đã', 'rất', 'may', 'mắn', 'vì', 'được', 'giúp', 'đỡ', 'rất', 'nhiều', 'người', ',', 'và', 'tôi', 'đã', 'giúp', 'đỡ', 'mình', 'để', 'giúp', 'đỡ', 'Hoa', 'Kỳ', 'và', 'giúp', 'đỡ', 'người', 'dân', 'Bắc']
# INPUT ['I', '&apos;m', 'confident', 'that', 'you', 'will', 'see', 'more', 'and', 'more', 'North', 'Koreans', 'succeeding', 'all', 'over', 'the', 'world', ',', 'including', 'the', 'TED', 'stage', '.']
# ...
# REF ['Đi', 'theo', 'lối', 'đó', ',', 'chúng', 'tôi', 'vạch', 'những', 'dây', 'leo', 'chắn', 'lối', ',', 'và', 'sau', 'khoảng', '1', 'giờ', 'đi', 'bộ', 'trong', 'rừng', ',', 'dấu', 'vết', 'đã', 'chìm', 'trong', 'nước', 'sau', 'những', 'trận', 'mưa', ',', 'nên', 'tôi', 'đội', 'dụng', 'cụ', 'chụp', 'hình', 'lên', 'đầu', 'khi', 'chúng', 'tôi', 'đi', 'xuống', 'dòng', 'nước', 'sâu', 'đến', 'ngực', '.']
# MT ['Khi', 'chúng', 'tôi', 'kéo', 'đường', 'dọc', 'qua', 'sông', ',', 'chúng', 'tôi', 'chuyển', 'qua', 'đường', 'ray', ',', 'và', 'sau', 'đó', 'tôi', 'chuyển', 'qua', 'đường', 'ray', ',', 'chúng', 'tôi', 'đã', 'hạ', 'cánh']
# INPUT ['After', 'another', 'two', 'hours', 'of', 'hiking', ',', 'the', 'winding', 'trail', 'abruptly', 'ended', 'at', 'a', 'clearing', ',', 'and', 'before', 'us', 'was', 'a', 'mass', 'of', 'holes', 'that', 'could', 'fit', 'into', 'the', 'size', 'of', 'a', 'football', 'field', ',', 'and', 'all', 'of', 'them', 'were', 'full', 'of', 'enslaved', 'people', 'laboring', '.']
# REF ['Sau', '2', 'giờ', 'cuốc', 'bộ', 'nữa', ',', 'dấu', 'vết', 'quanh', 'co', 'bất', 'ngờ', 'kết', 'thúc', 'tại', 'khu', 'đất', 'trống', ',', 'và', 'trước', 'mắt', 'chúng', 'tôi', 'là', 'một', 'vùng', 'la', 'liệt', 'những', 'cái', 'hố', 'rộng', 'bằng', 'cả', 'sân', 'bóng', 'đá', ',', 'chúng', 'chứa', 'đầy', 'những', 'nhân', 'công', 'nô', 'lệ', '.']
# MT ['Sau', 'một', 'khoảng', 'hai', 'trăm', 'con', 'tàu', ',', 'con', 'tàu', 'đã', 'nổ', 'tung', ',', 'trước', 'khi', 'ném', 'đá', ',', 'và', 'mỗi', 'con', 'tàu', 'đã', 'kéo', 'dài', 'gần', 'như', 'đống', 'đá']
# INPUT ['Many', 'women', 'had', 'children', 'strapped', 'to', 'their', 'backs', 'while', 'they', 'were', 'panning', 'for', 'gold', ',', 'wading', 'in', 'water', 'poisoned', 'by', 'mercury', '.']
# REF ['Nhiều', 'phụ', 'nữ', 'địu', 'con', 'trên', 'lưng', 'trong', 'khi', 'đãi', 'vàng', ',', 'và', 'lội', 'qua', 'dòng', 'nước', 'nhiễm', 'độc', 'thuỷ', 'ngân', '.']
# MT ['Nhiều', 'phụ', 'nữ', 'trẻ', 'phải', 'cưỡng', 'bức', 'nước', 'ép', 'buộc', 'phải', 'quay', 'lại', 'khi', 'họ', 'bị', 'cắt', ',', 'nước', 'mưa', 'tràn', 'vào', 'nước', 'bị', 'ảnh', 'hưởng', 'bởi', 'nước', 'bị', 'nhiễm']
# INPUT ['Mercury', 'is', 'used', 'in', 'the', 'extraction', 'process', '.']
# REF ['Thuỷ', 'ngân', 'được', 'dùng', 'trong', 'quá', 'trình', 'chiết', 'xuất', '.']
# MT ['<unk>', 'được', 'sử', 'dụng', 'trong', 'quá', 'trình', 'tiến', 'hoá', 'của', 'quá', 'trình', '.']
# INPUT ['These', 'miners', 'are', 'enslaved', 'in', 'a', 'mine', 'shaft', 'in', 'another', 'part', 'of', 'Ghana', '.']
# REF ['Những', 'người', 'thợ', 'mỏ', 'này', 'bị', 'bắt', 'làm', 'nô', 'lệ', 'trong', 'hầm', 'mỏ', 'ở', '1', 'khu', 'vực', 'khác', 'của', 'Ghana', '.']
# MT ['Những', 'chiếc', 'xe', 'đạp', 'ở', 'đây', 'được', 'đặt', 'ở', 'một', 'trong', 'những', 'điểm', 'khác', 'của', 'vùng', 'ngoại', 'ô', 'khác', 'nhau', '.']
# INPUT ['When', 'they', 'came', 'out', 'of', 'the', 'shaft', ',', 'they', 'were', 'soaking', 'wet', 'from', 'their', 'own', 'sweat', '.']
# REF ['Khi', 'ra', 'khỏi', 'hầm', ',', 'người', 'họ', 'ướt', 'sũng', 'bởi', 'mồ', 'hôi', 'của', 'chính', 'mình', '.']
# MT ['Khi', 'họ', 'thoát', 'khỏi', 'ruột', ',', 'họ', 'bị', 'tách', 'khỏi', 'bàn', 'mổ', 'của', 'chính', 'mình', 'bị', 'mất', 'máu', '.']
# INPUT ['I', 'remember', 'looking', 'into', 'their', 'tired', ',', 'bloodshot', 'eyes', ',', 'for', 'many', 'of', 'them', 'had', 'been', 'underground', 'for', '72', 'hours', '.']
# REF ['Tôi', 'vẫn', 'nhớ', 'khi', 'nhìn', 'vào', 'đôi', 'mắt', 'đỏ', 'quạch', ',', 'mệt', 'mỏi', 'của', 'họ', 'vì', 'nhiều', 'người', 'đã', 'ở', 'dưới', 'lòng', 'đất', 'tới', '72', 'giờ', '.']
# MT ['Tôi', 'nhớ', 'mình', 'đã', 'nhìn', 'thấy', 'rất', 'nhiều', 'đậu', ',', 'vắt', 'sữa', 'bò', 'suốt', 'hàng', 'giờ', 'đồng', 'hồ', ',', 'làm', 'việc', 'trong', '24', 'giờ', 'đồng', 'hồ', '.']
# INPUT ['The', 'shafts', 'are', 'up', 'to', '300', 'feet', 'deep', ',', 'and', 'they', 'carry', 'out', 'heavy', 'bags', 'of', 'stone', 'that', 'later', 'will', 'be', 'transported', 'to', 'another', 'area', ',', 'where', 'the', 'stone', 'will', 'be', 'pounded', 'so', 'that', 'they', 'can', 'extract', 'the', 'gold', '.']
# REF ['Những', 'cái', 'hầm', 'sâu', 'tới', 'cả', 'trăm', 'mét', ',', 'họ', 'vác', 'lên', 'những', 'chiếc', 'túi', 'đá', 'nặng', 'trĩu', 'để', 'chuyển', 'chúng', 'tới', 'khu', 'vực', 'khác', ',', 'nơi', 'đá', 'được', 'nghiền', 'ra', 'để', 'đãi', 'lấy', 'vàng', '.']
# MT ['<unk>', 'trưởng', 'được', 'bao', 'phủ', 'bởi', 'một', 'vòng', 'tròn', 'lớn', ',', 'và', 'nó', 'sẽ', 'được', 'lấp', 'đầy', 'khoảng', '1', 'foot', 'nặng', 'hơn', 'nữa', ',', 'chúng', 'có', 'thể', 'được', 'trang', 'bị']
# INPUT ['At', 'first', 'glance', ',', 'the', 'pounding', 'site', 'seems', 'full', 'of', 'powerful', 'men', ',', 'but', 'when', 'we', 'look', 'closer', ',', 'we', 'see', 'some', 'less', 'fortunate', 'working', 'on', 'the', 'fringes', ',', 'and', 'children', 'too', '.']
# REF ['Nhìn', 'qua', ',', 'công', 'trường', 'đập', 'đá', 'có', 'vẻ', 'đầy', 'những', 'người', 'khoẻ', 'mạnh', ',', 'nhưng', 'khi', 'nhìn', 'lại', 'gần', ',', 'có', 'những', 'nhiều', 'kém', 'may', 'mắn', 'hơn', 'làm', 'việc', 'trong', 'tình', 'trạng', 'khắc', 'nghiệt', ',', 'có', 'cả', 'trẻ', 'em', '.']
# MT ['Ban', 'đầu', ',', '63', 'lần', 'căng', 'thẳng', ',', 'người', 'lớn', 'tuổi', 'nhất', 'có', 'nhiều', 'người', 'trông', 'trẻ', 'hơn', ',', 'nhưng', 'chúng', 'tôi', 'cũng', 'quan', 'sát', 'một', 'số', 'ít', 'các', 'cặp']
# INPUT ['All', 'of', 'them', 'are', 'victim', 'to', 'injury', ',', 'illness', 'and', 'violence', '.']
# REF ['Họ', 'đều', 'là', 'nạn', 'nhân', 'của', 'tổn', 'thương', ',', 'bệnh', 'tật', 'và', 'bạo', 'lực', '.']
# MT ['Tất', 'cả', 'chúng', 'ta', 'đều', 'bị', 'nạn', 'đói', ',', 'nạn', 'đói', 'và', 'bạo', 'lực', '.']
# INPUT ['In', 'fact', ',', 'it', '&apos;s', 'very', 'likely', 'that', 'this', 'muscular', 'person', 'will', 'end', 'up', 'like', 'this', 'one', 'here', ',', 'racked', 'with', 'tuberculosis', 'and', 'mercury', 'poisoning', 'in', 'just', 'a', 'few', 'years', '.']
# REF ['Thực', 'tế', ',', 'nhiều', 'khả', 'năng', 'người', 'cơ', 'bắp', 'này', 'cuối', 'cùng', 'sẽ', 'giống', 'người', 'này', ',', 'bị', 'bệnh', 'lao', 'hành', 'hạ', 'và', 'nhiễm', 'độc', 'thuỷ', 'ngân', 'trong', 'vài', 'năm', 'nữa', '.']
# MT ['Thực', 'ra', ',', 'người', 'này', 'sẽ', 'có', 'thể', 'chết', ',', 'Hoàn', 'toàn', 'không', 'thể', 'can', 'thiệp', 'vào', 'điều', 'này', ',', 'với', 'một', 'vài', 'năm', 'và', 'trong', 'vài', 'năm', 'tới', ',']
# INPUT ['This', 'is', 'Manuru', '.', 'When', 'his', 'father', 'died', ',', 'his', 'uncle', 'trafficked', 'him', 'to', 'work', 'with', 'him', 'in', 'the', 'mines', '.']
# REF ['Đây', 'là', 'Manuru', '.', 'Khi', 'cha', 'mất', ',', 'anh', 'ta', 'được', 'người', 'chú', 'đưa', 'đến', 'khu', 'mỏ', 'làm', 'việc', 'cùng', '.']
# MT ['<unk>', '<unk>', ',', 'ông', 'rời', 'bỏ', 'bệnh', 'nhân', 'của', 'ông', 'ấy', '.', 'Ông', 'làm', 'việc', 'với', 'vợ', 'của', 'ông', ',', 'với', 'những', 'người', 'đã', 'làm', 'việc', 'trong', 'ngành', 'y', 'tế']
# INPUT ['When', 'his', 'uncle', 'died', ',', 'Manuru', 'inherited', 'his', 'uncle', '&apos;s', 'debt', ',', 'which', 'further', 'forced', 'him', 'into', 'being', 'enslaved', 'in', 'the', 'mines', '.']
# REF ['Khi', 'người', 'chú', 'mất', ',', 'Manuru', 'kế', 'thừa', 'món', 'nợ', 'của', 'chú', ',', 'và', 'bị', 'buộc', 'làm', 'nô', 'lệ', 'trong', 'khu', 'mỏ', 'này', 'lâu', 'hơn', 'nữa', '.']
# MT ['Khi', 'ông', 'mất', 'đi', ',', 'ông', 'ấy', 'bị', 'giết', 'chết', 'trong', 'cơn', 'đau', 'đớn', 'tột', 'cùng', 'của', 'mình', ',', 'nó', 'sẽ', 'bị', 'đưa', 'vào', 'trong', 'những', 'cái', 'hồ', 'sơ', 'bệnh']
# INPUT ['When', 'I', 'met', 'him', ',', 'he', 'had', 'been', 'working', 'in', 'the', 'mines', 'for', '14', 'years', ',', 'and', 'the', 'leg', 'injury', 'that', 'you', 'see', 'here', 'is', 'actually', 'from', 'a', 'mining', 'accident', ',', 'one', 'so', 'severe', 'doctors', 'say', 'his', 'leg', 'should', 'be', 'amputated', '.']
# REF ['Khi', 'tôi', 'gặp', ',', 'anh', 'ta', 'đã', 'làm', 'việc', '14', 'năm', 'ở', 'khu', 'mỏ', ',', 'và', 'vết', 'thương', 'ở', 'chân', 'mà', 'bạn', 'thấy', 'đây', 'là', 'từ', '1', 'tai', 'nạn', 'ở', 'mỏ', ',', 'một', 'chân', 'bị', 'thương', 'nặng', 'đến', 'nỗi', 'bác', 'sĩ', 'nói', 'phải', 'cưa', 'đi', '.']
# MT ['Khi', 'tôi', 'gặp', 'ông', 'ấy', ',', 'người', 'mà', 'ông', 'đã', 'chứng', 'kiến', 'năm', '1996', ',', 'ông', 'đã', 'chứng', 'kiến', 'một', 'sự', 'tiến', 'triển', 'rất', 'mạnh', 'mẽ', 'rằng', 'ông', 'đã', 'bị']
# INPUT ['On', 'top', 'of', 'that', ',', 'Manuru', 'has', 'tuberculosis', ',', 'yet', 'he', '&apos;s', 'still', 'forced', 'to', 'work', 'day', 'in', 'and', 'day', 'out', 'in', 'that', 'mine', 'shaft', '.']
# REF ['Trên', 'hết', ',', 'Manuru', 'bị', 'bệnh', 'lao', ',', 'nhưng', 'vẫn', 'bị', 'bắt', 'làm', 'việc', 'ngày', 'qua', 'ngày', 'tại', 'hầm', 'mỏ', 'đó', '.']
# MT ['Trên', 'hết', ',', 'điều', 'đó', 'đã', 'mất', ',', 'nhưng', 'ngày', 'hôm', 'sau', 'vẫn', 'mất', 'kiểm', 'soát', 'và', 'bố', 'mẹ', 'vẫn', 'còn', 'sống', 'trong', 'tù', '.']
# INPUT ['Even', 'still', ',', 'he', 'has', 'a', 'dream', 'that', 'he', 'will', 'become', 'free', 'and', 'become', 'educated', 'with', 'the', 'help', 'of', 'local', 'activists', 'like', 'Free', 'the', 'Slaves', ',', 'and', 'it', '&apos;s', 'this', 'sort', 'of', 'determination', ',', 'in', 'the', 'face', 'of', 'unimaginable', 'odds', ',', 'that', 'fills', 'me', 'with', 'complete', 'awe', '.']
# REF ['Dù', 'vậy', ',', 'anh', 'ta', 'vẫn', 'mơ', 'ước', 'được', 'tự', 'do', 'được', 'đi', 'học', 'với', 'sự', 'giúp', 'đỡ', 'của', 'những', 'nhà', 'hoạt', 'động', 'địa', 'phương', 'như', 'tổ', 'chức', 'Giải', 'phóng', 'Nô', 'lệ', ',', 'và', 'quyết', 'tâm', 'như', 'thế', 'này', ',', 'hiện', 'lên', 'trên', 'khuôn', 'mặt', 'của', 'những', 'người', 'lạ', 'thường', ',', 'khiến', 'tôi', 'ngập', 'tràn', 'sự', 'nể', 'phục', '.']
# MT ['Ngay', 'cả', 'khi', 'ông', 'ấy', 'trở', 'về', 'nhà', ',', 'ông', 'ấy', 'trở', 'thành', 'một', 'nhà', 'lãnh', 'đạo', 'và', 'nhà', 'lãnh', 'đạo', ',', 'và', 'chính', 'phủ', 'này', 'sẽ', 'trở', 'thành', 'một']
# INPUT ['I', 'want', 'to', 'shine', 'a', 'light', 'on', 'slavery', '.']
# REF ['Tôi', 'muốn', 'đưa', 'nô', 'lệ', 'ra', 'ánh', 'sáng', '.']
# MT ['Tôi', 'muốn', 'mở', 'rộng', 'một', 'quỹ', 'đạo', 'cấp', 'cao', 'của', 'nền', 'văn', 'minh', '.']
# INPUT ['When', 'I', 'was', 'working', 'in', 'the', 'field', ',', 'I', 'brought', 'lots', 'of', 'candles', 'with', 'me', ',', 'and', 'with', 'the', 'help', 'of', 'my', 'interpreter', ',', 'I', 'imparted', 'to', 'the', 'people', 'I', 'was', 'photographing', 'that', 'I', 'wanted', 'to', 'illuminate', 'their', 'stories', 'and', 'their', 'plight', ',', 'so', 'when', 'it', 'was', 'safe', 'for', 'them', ',', 'and', 'safe', 'for', 'me', ',', 'I', 'made', 'these', 'images', '.']
# REF ['Khi', 'làm', 'việc', 'trong', 'lãnh', 'vực', 'này', ',', 'tôi', 'mang', 'theo', 'rất', 'nhiều', 'nến', ',', 'với', 'sự', 'giúp', 'đỡ', 'của', 'người', 'phiên', 'dịch', ',', 'tôi', 'truyền', 'đạt', 'với', 'những', 'người', 'mà', 'mình', 'chụp', 'hình', 'rằng', 'tôi', 'muốn', 'soi', 'sáng', 'câu', 'chuyện', 'và', 'hoàn', 'cảnh', 'của', 'họ', ',', 'rồi', 'khi', 'họ', 'và', 'tôi', 'được', 'an', 'toàn', 'tôi', 'chụp', 'những', 'tấm', 'hình', 'này', '.']
# MT ['Khi', 'tôi', 'đang', 'làm', 'việc', 'ở', 'nhà', ',', 'tôi', 'rất', 'vinh', 'dự', 'được', 'mời', 'tham', 'gia', 'vào', 'khuôn', 'viên', 'của', 'họ', 'và', 'tôi', 'đã', 'mời', 'mọi', 'người', 'đến', 'với', 'tôi']
# INPUT ['They', 'knew', 'their', 'image', 'would', 'be', 'seen', 'by', 'you', 'out', 'in', 'the', 'world', '.']
# REF ['Họ', 'biết', 'hình', 'của', 'họ', 'sẽ', 'được', 'xem', 'bởi', 'những', 'người', 'ở', 'ngoài', 'kia', ',', 'như', 'bạn']
# MT ['Họ', 'đã', 'biết', 'rằng', 'họ', 'sẽ', 'thấy', 'họ', 'là', 'thế', 'giới', 'của', 'bạn', 'được', 'thế', 'giới', 'theo', 'cách', 'riêng', 'của', 'mình', '.']
# INPUT ['I', 'wanted', 'them', 'to', 'know', 'that', 'we', 'will', 'be', 'bearing', 'witness', 'to', 'them', ',', 'and', 'that', 'we', 'will', 'do', 'whatever', 'we', 'can', 'to', 'help', 'make', 'a', 'difference', 'in', 'their', 'lives', '.']
# REF ['Tôi', 'muốn', 'họ', 'biết', 'rằng', 'chúng', 'ta', 'sẽ', 'làm', 'chứng', 'cho', 'họ', ',', 'và', 'ta', 'sẽ', 'làm', 'bất', 'cứ', 'gì', 'có', 'thể', 'để', 'giúp', 'họ', 'thay', 'đổi', 'cuộc', 'đời', '.']
# MT ['Tôi', 'muốn', 'biết', 'rằng', 'chúng', 'ta', 'sẽ', 'làm', 'gì', 'với', 'họ', ',', 'chúng', 'ta', 'có', 'thể', 'làm', 'được', 'điều', 'đó', ',', 'và', 'chúng', 'ta', 'có', 'thể', 'giúp', 'đỡ', 'họ', 'để']
# INPUT ['I', 'truly', 'believe', ',', 'if', 'we', 'can', 'see', 'one', 'another', 'as', 'fellow', 'human', 'beings', ',', 'then', 'it', 'becomes', 'very', 'difficult', 'to', 'tolerate', 'atrocities', 'like', 'slavery', '.']
# REF ['Tôi', 'thực', 'sự', 'tin', ',', 'nếu', 'ta', 'coi', 'người', 'khác', 'như', 'những', 'người', 'đồng', 'loại', ',', 'thì', 'sẽ', 'rất', 'khó', 'để', 'khoan', 'hồng', 'những', 'tội', 'ác', 'như', 'nạn', 'nô', 'lệ', '.']
# MT ['Tôi', 'tin', 'rằng', ',', 'một', 'người', 'nào', 'đó', 'có', 'thể', 'thấy', 'tiềm', 'năng', 'rất', 'khác', 'so', 'với', 'con', 'người', ',', 'thì', 'chúng', 'ta', 'dường', 'như', 'trở', 'nên', 'vô', 'cùng', 'khó']
# INPUT ['These', 'images', 'are', 'not', 'of', 'issues', '.', 'They', 'are', 'of', 'people', ',', 'real', 'people', ',', 'like', 'you', 'and', 'me', ',', 'all', 'deserving', 'of', 'the', 'same', 'rights', ',', 'dignity', 'and', 'respect', 'in', 'their', 'lives', '.']
# REF ['Những', 'tấm', 'hình', 'không', 'phải', 'là', 'về', 'bản', 'thân', 'vấnđề', '.', 'Chúng', 'là', 'về', 'con', 'người', ',', 'người', 'thật', ',', 'như', 'bạn', 'và', 'tôi', ',', 'tất', 'cả', 'đều', 'xứng', 'đáng', 'hưởng', 'quyền', 'bằng', 'nhau', ',', 'danh', 'dự', 'và', 'tôn', 'trọng', 'như', 'nhau', 'trong', 'đời', '.']
# MT ['Những', 'hình', 'ảnh', 'này', 'không', 'phải', 'là', 'bất', 'ngờ', '.', 'Họ', 'là', 'những', 'người', ',', 'như', 'tất', 'cả', 'các', 'bạn', ',', 'là', 'những', 'người', 'chúng', 'ta', ',', 'như', 'tôi', ',']
# INPUT ['There', 'is', 'not', 'a', 'day', 'that', 'goes', 'by', 'that', 'I', 'don', '&apos;t', 'think', 'of', 'these', 'many', 'beautiful', ',', 'mistreated', 'people', 'I', '&apos;ve', 'had', 'the', 'tremendous', 'honor', 'of', 'meeting', '.']
# REF ['Không', 'có', 'ngày', 'nào', 'mà', 'tôi', 'không', 'nghĩ', 'về', 'những', 'người', 'tuyệt', 'vời', 'bị', 'vùi', 'dập', 'này', '.', 'Tôi', 'có', 'vinh', 'dự', 'to', 'lớn', 'được', 'gặp', 'gỡ', 'họ', '.']
# MT ['Không', 'có', 'ngày', 'nào', ',', 'tôi', 'nghĩ', 'về', 'những', 'người', 'tuyệt', 'vời', 'này', ',', 'tôi', 'đã', 'có', 'một', 'số', 'người', 'tuyệt', 'vời', 'nhất', 'mà', 'đã', 'từng', 'có', 'những', 'người', 'lớn']
# INPUT ['I', 'hope', 'that', 'these', 'images', 'awaken', 'a', 'force', 'in', 'those', 'who', 'view', 'them', ',', 'people', 'like', 'you', ',', 'and', 'I', 'hope', 'that', 'force', 'will', 'ignite', 'a', 'fire', ',', 'and', 'that', 'fire', 'will', 'shine', 'a', 'light', 'on', 'slavery', ',', 'for', 'without', 'that', 'light', ',', 'the', 'beast', 'of', 'bondage', 'can', 'continue', 'to', 'live', 'in', 'the', 'shadows', '.']
# REF ['Tôi', 'hi', 'vọng', 'những', 'tấm', 'hình', 'sẽ', 'đánh', 'thức', 'một', 'nguồn', 'sức', 'mạnh', 'trong', 'người', 'xem', ',', 'những', 'người', 'như', 'bạn', ',', 'và', 'hi', 'vọng', 'sức', 'mạnh', 'đó', 'sẽ', 'châm', 'ngọn', 'lửa', ',', 'ngọn', 'lửa', 'đó', 'sẽ', 'chiếu', 'rọi', 'vào', 'nạn', 'nô', 'lệ', ',', 'vì', 'không', 'có', 'ánh', 'sáng', 'đó', ',', 'con', 'quái', 'vật', 'của', 'ngục', 'tù', 'sẽ', 'có', 'thể', 'tiếp', 'tục', 'sống', 'trong', 'bóng', 'tối', '.']
# MT ['Tôi', 'hy', 'vọng', 'những', 'hình', 'ảnh', 'này', 'trông', 'như', 'thế', 'này', ',', 'những', 'người', 'có', 'thể', 'gieo', 'trồng', ',', 'và', 'tôi', 'hy', 'vọng', 'rằng', 'các', 'bạn', 'sẽ', 'thấy', 'một', 'nền']
# INPUT ['Thank', 'you', 'very', 'much', '.']
# REF ['Cảm', 'ơn', 'rất', 'nhiều', '.']
# MT ['Cảm', 'ơn', 'các', 'bạn', 'rất', 'nhiều', '.']
# total: 1268
# bleu: 0.0937042105938829
